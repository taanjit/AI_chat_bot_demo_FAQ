# %% [markdown]
# ## Document Ingestion

# %%
import os
import warnings
from dotenv import load_dotenv

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'  # if using chroma nd faiss in same environment
warnings.filterwarnings("ignore")

load_dotenv()
# Out:
# True

# %%
os.environ['LANGCHAIN_PROJECT']
# Out:
# 'chatmypdf'

# %%
from docling.document_converter import DocumentConverter
from pathlib import Path
source = Path("/home/tadmnit/AI_Team/Anjit/AI_chat_bot_demo_FAQ/Smart_Business_IoT_Pdf.pdf")

# %%
from docling.datamodel.base_models import InputFormat
from docling.document_converter import (
    DocumentConverter,
    PdfFormatOption,
    WordFormatOption,
)
from docling.pipeline.simple_pipeline import SimplePipeline
from docling.pipeline.standard_pdf_pipeline import StandardPdfPipeline
from docling.backend.pypdfium2_backend import PyPdfiumDocumentBackend

# %%
converter = DocumentConverter(
    allowed_formats=[InputFormat.PDF],  # Or other formats you need
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_cls=StandardPdfPipeline,
            backend=PyPdfiumDocumentBackend
        )
    }
)

# %%
conv_result = converter.convert(source)

# %%
from langchain_core.documents import Document as LCDocument
if conv_result and conv_result.document:
    lc_docs = LCDocument(page_content=conv_result.document.export_to_markdown())
    print("Successfully created LCDocument")
else:
    print("Conversion failed or produced no document")

# Now you can use lc_doc
print(lc_docs)
# Out:
# Successfully created LCDocument
# page_content='## Introduction
#
# The Smart Business IoT application allows the user to view and manage the data of various sensors installed on different sites. The user can monitor data focusing on light intensity, temperature, humidity, and carbon dioxide levels through installed devices. The application connects multiple sites and acts as a single data point. The user can add events, set event rules, generate reports based on the collected data, and manage administration through the application.
#
# ## Login
#
# The login page enables the user to access the Smart Business IoT application using the credentials. Once logged in, the user can navigate the application and explore the features.
#
# Perform the following steps to log in to Smart Business IoT:
#
# 1. Launch any web browser and enter the application's URL to log in. The login page appears.
# 2. Enter the Email address and Password in the respective fields.
# 3. Click Login .
#
# <!-- image -->
#
# <!-- image -->
#
# ## Reset Password
#
# The user can recover the account through the Forgot your password? feature.
#
# To reset the password, click Forgot your password? on the login page. The Reset your password section appears.
#
# <!-- image -->
#
# <!-- image -->
#
# Enter the email address associated with the account and click Send .
#
# A password reset link is sent to the registered email id. Follow the instructions in the mail to reset the password
#
# ## Home
#
# Home is the landing page of the application. The Home page displays the location of the sites on the map. The following page appears when the user logs in:
#
# <!-- image -->
#
# <!-- image -->
#
# The Home page represents each site location using the icon. The user can also find the number of alerts from the respective sites along with the icon. Click on the site location to access the site dashboard.
#
# ## NetvirE Retail
#
# Click Sites to view the list of all sites. The Sites pop-up appears.
#
# <!-- image -->
#
# Search for the required site from the list using the Search Site option.
#
# The Sites pop-up displays the list of all sites along with the following information:
#
# - Number of devices installed on the sites.
# - Number of gateways connected to the sites.
# - Number of alarms generated on the site.
#
# The user can view the site location on the map using the icon. Click View to navigate to the site dashboard. For more information, see Site DashboardSite Dashboard .
#
# ## Site Dashboard
#
# The site dashboard provides the user with the status, history, and statistics of the devices installed on the site. The user can access the site dashboard from the site location icon on the map or through the Sites pop-up. The site dashboard appears as follows:
#
# <!-- image -->
#
# The site dashboard provides the user with the following options:
#
# - Status: Displays the current status of the devices installed on the site along with the last connected date and time.
#
# <!-- image -->
#
# - History: Displays the history of the devices installed on the site using graphical representations.
#
# <!-- image -->
#
# The graph is plotted using the measured value of each device against time.
#
# Hover over the graph to view the history at a given point of time.
#
# - Detail: Displays the statistics of the devices installed on the site along with the respective graphs.
#
# <!-- image -->
#
# The Detail tab also provides the following information about the sites:
#
# - Number of active
# - and inactive
#
# <!-- image -->
#
# gateways.
#
# - Number of active and inactive devices.
# - Number of events generated on the site categorized as follows:
# - Critical
# - Major
# - Minor
# - Events
# - : Displays the number of events generated on the site.
# - Refresh: Allows the user to refresh the contents on the site dashboard.
# - Last updated: Displays the date and time when the data is last updated.
# - Name: Allows the user to filter the data based on the device name.
# - Type: Allows the user to filter the data based on the device type.
# - Date filter: Allows the user to filter the data based on predefined time intervals. The information displayed on the page is set to display data from the Past 1 day by default.
#
# <!-- image -->
#
# <!-- image -->
#
# The application also provides the option to view data within a custom range filter according to user preference. Click Custom range from the drop-down and select the required date and time range from the Select date range calendar.
#
# Note: The Custom range filter appears only when the user opens the History and Detail tab.
#
# ## Dashboard
#
# The Dashboard provides users with information about the devices installed at all locations. Users can view the status, history, and statistics of each device on the sites. Click Dashboard from the left panel. The following page appears:
#
# <!-- image -->
#
# The Dashboard provides the user with the following options:
#
# - Status: Displays the current status of the devices installed along with the last connected date and time. Click on the site icon on the device information to go to the site dashboard.
#
# NetvirE Retail
#
# <!-- image -->
#
# To change the layout of the dashboard, drag the sensor information to the required position and click Save. The Save button appears only when the user changes the layout. Click Reset to reset the previous layout.
#
# - History: Displays the history of the devices installed using graphical representations.
#
# <!-- image -->
#
# The graph is plotted using the measured value of each device against time. Hover over the graph to view the history at a given point of time.
#
# - Detail: Displays the statistics of the devices installed along with the respective graphs.
#
# ## NetvirE Retail
#
# <!-- image -->
#
# The Detail tab also provides the following information:
#
# - Number of active
# - •
# - and inactive
# - Number of active and inactive
#
# gateways.
#
# devices.
#
# <!-- image -->
#
# <!-- image -->
#
# - Number of events generated on the site categorized as follows:
# - Critical
# - Major
# - Minor
# - Events
# - : Displays the number of events generated.
# - Refresh: Allows the user to refresh the contents on the dashboard.
# - Last updated: Displays the date and time when the data is last updated.
# - Name: Allows the user to filter the data based on the device name.
# - Type: Allows the user to filter the data based on the device type.
# - Date filter: Allows the user to filter the data based on predefined time intervals.
# - The information displayed on the page is set to display data from the Past 1 day by default.
#
# <!-- image -->
#
# The application also provides the option to view data within a custom range filter according to user preference. Click Custom range from the drop-down and select the required date and time range from the Select date range calendar.
#
# Note: The Custom range filter appears only when the user opens the History and Detail tab.
#
# ## Events
#
# An event is triggered when the data from the sensor meets certain predefined conditions or rules. The users are notified using an alarm whenever an alarm occurs.
#
# The Events page monitors and keeps track of the events generated on the sites. The user can manage and view the event list on the Events page.
#
# Click Events from the left panel. The following page appears:
#
# <!-- image -->
#
# The Events page provides the following information:
#
# - Events: Displays the number of events generated categorized as follows:
# - Critical
# - Major
# - Minor
# - Click Event Rules to add an event rule. For more information, see Event RulesEvent Rules. Use the Refresh button to refresh the information on the page.
# - Last 7 Days Event Status: Displays the graphical representation of the event statuses from the last 7 days. The event statuses are categorized into the following:
# - Unresolved
#
# ## · Resolved
#
# - Event list: Displays the list of events generated with the following fields:
# - Created At: Displays the date and time of the event generation.
# - Event: Displays the title of the event.
# - Device/ Gateway Name: Displays the device or gateway where the event is generated.
# - Severity: Displays the severity of the event.
# - Event State: Displays the state of the event.
# - Action: Displays the actions available on the event. The actions are:
# - Acknowledge
# - Clear
#
# ## Acknowledge Event
#
# The acknowledge event option allows the user to mark an event as acknowledged for further actions.
#
# Perform the following steps to acknowledge an event:
#
# 1. Click against the respective event.
#
# <!-- image -->
#
# The following pop-up appears:
#
# <!-- image -->
#
# - Do you want to acknowledge this event?
# 2. Click Yes to acknowledge the event or No to cancel.
#
# <!-- image -->
#
# To acknowledge multiple events, select the required events and click the Acknowledge button at the top of the event list.
#
# ## Clear Event
#
# The clear event option allows the user to mark an event as closed.
#
# Perform the following steps to clear an event:
#
# 1. Click against the respective event.
#
# <!-- image -->
#
# The following pop-up appears:
#
# - Do you want to clear this event?
# 2. Click Yes to clear the event or No to cancel.
#
# <!-- image -->
#
# To clear multiple events, select the required events and click Clear at the top of the event list.
#
# The user can manage the display preferences of the events list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).
# - Click next to the column name to filter the list and display only the preferred items.
# - Use the pagination option to navigate between different sections of the list.
# - Use the page size selector to choose the number of items displayed at a time.
#
# ## Event Rules
#
# Event Rules are a set of user -defined conditions that detect events when the sensor data meets the conditions and triggers a corresponding action. The Event Rules page enables the user to create and manage event rules.
#
# Click Event Rules from the Events page. The following page appears:
#
# <!-- image -->
#
# The Event Rules page displays the list of event rules created with the following fields:
#
# - Rule: Displays the title of the event rule.
# - Action: Displays the action corresponding to the rule.
# - Users: Displays the users to notify during the event.
# - State: Displays the current state of the rule.
# - Edit
# - Delete
#
# <!-- image -->
#
# <!-- image -->
#
# Click to view the history of the event rule. The events generated from the particular rule appear as follows:
#
# <!-- image -->
#
# - Click to acknowledge the event. For more information, see Acknowledge EvenAcknowledge Event .
# - Click to clear the event. For more information, see Clear EventClear Event .
#
# ## Add Event Rule
#
# The Add Event Rule option allows the user to create an event rule. Perform the following steps to add a new event rule:
#
# 1. Click Add Event Rule on the Event Rules page.
#
# <!-- image -->
#
# ## The Add event rule pop-up appears.
#
# <!-- image -->
#
# Cancel
#
# <!-- image -->
#
# ## 2. Fill in the following fields:
#
# - a. Rule: Enter the title of the rule.
#
# - b. Add Condition: Click Add Condition to add the rule. The following fields appear:
# - i. Merge Condition: The Merge Condition field is enabled only when at least one condition is added. Select the required option from the drop-down to merge the conditions.
# - ii. Gateway/Device: Select the required option from the Gateway/Device drop-down.
# 1. Gateway: Allows the user to define the event rule based on the gateways.
# 2. Device: Allows the user to define the event rule based on the devices.
# - iii. Filter by: Select the required filter option from the drop-down.
# 7. For the Gateway option, the following filter options appear:
# 1. Any: Allows the user to select all the devices.
# 2. Gateway: Allows the user to select a specific gateway.
# - iv. For the Device option, the following filter options appear:
# 1. Any: Allows the user to select all the devices.
# 2. Device type: Allows the user to select a device of a specific type.
# 3. Device name: Allows the user to select a specific device.
# - v. Property: Select the required property from the drop-down.
# - vi. Operator: Select the required operator from the drop-down.
#
# <!-- image -->
#
# - vii. Value: Enter the required threshold value.
#
# - viii. Time Period: Select the required time period option from the drop- down. The available options are:
#
# 1. N/A: Select N/A if time period is not applicable.
#
# 2. Duration: Allows the user to specify a particular time duration. Enter the required time duration in the Time field that appears below.
#
# 3. Interval: Allows the user to select a time interval. Select the required interval from the Start Time and End Time fields that appear below.
#
# - ix. Click Add to submit the condition or Cancel to clear the condition.
#
# - c. Event: Enter the event description. Click
#
# to view and select the
#
# - dynamic fields. Copy and paste the required options in the field. The application replaces the fields with actual values.
#
# - d. Severity: Select the severity of the event from the drop-down. The available options are:
#
# - i. Major
#
# - ii. Minor
#
# - iii. Critical
#
# - e. Notes: Enter the comments or notes, if any. Click
#
# - [ ] to view and select
#
# the dynamic fields. Copy
#
# and paste the required options in the field.
#
# The application replaces the fields with actual values.
#
# - f. Event Report Filter: Enter the threshold time interval to detect the events to avoid repeated triggers.
#
# - g. Event Action Type: Select the required event action type from the drop- down. The available actions are:
#
# - i. SMS: The SMS Text field appears when the user selects the SMS option in the Event Action Type field. Enter the message required
#
# ## to send to the recipients.
#
# <!-- image -->
#
# <!-- image -->
#
# Click to view and select the dynamic fields. Copy and paste the required options in the field. The application replaces the fields with actual values.
#
# - h. Event Recipient(s): Select the users to notify during the event from the drop-down.
# 3. Select the Enable checkbox to enable the rule and click Submit .
#
# ## Edit Event Rule
#
# The application enables users to update and manage the existing rules using the edit option. Perform the following steps to edit a rule:
#
# 1.
#
# Click against the respective event rule.
#
# <!-- image -->
#
# ## The Edit event rule pop-up appears.
#
# <!-- image -->
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Event Rule
#
# The delete option allows the user to remove an event rule. Perform the following steps to delete an event rule:
#
# 1. Click against the respective event rule.
#
# <!-- image -->
#
# The following pop-up appears:
#
# - Do you want to delete this rule?
# 2. Click Yes to delete the rule or No to cancel.
#
# <!-- image -->
#
# The user can manage the display preferences of the Event Rules list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).
# - Click next to the column name to filter the list and display only the preferred items.
# - Use the pagination
#
# <!-- image -->
#
# to
#
# <!-- image -->
#
# - Use the page size selector displayed at a time.
#
# to choose the number of items
#
# ## Reports
#
# Reports help the users to track and analyze the events generated on the sites. The Reports page on the application enables the user to create and manage reports using table and chart representation.
#
# Click Reports on the left panel. The Reports page appears as follows:
#
# <!-- image -->
#
# The Reports page displays the list of reports created with the following fields:
#
# - Report Name: Displays the name of the report.
# - Interval: Displays the selected time interval for report generation.
# - Report Type: Displays the type of the report generated.
# - Action: Displays the action available for the report. The actions are:
# - Generate report
# - Edit report
# - Delete report
#
# Click to view the history of the report. The details of the generated report appear here.
#
# ## NetvirE Retail
#
# Click Download to download the report and
#
# <!-- image -->
#
# ## Add Report
#
# The Add Report option allows the user to add a new report.
#
# Perform the following steps to add a report:
#
# 1. Click Add Report on the Reports page.
#
# to delete the report.
#
# <!-- image -->
#
# ## The Add Report pop-up appears.
#
# ## Add Report
#
# <!-- image -->
#
# Submit
#
# ## 2. Fill in the following fields:
#
# 1. Report Name: Enter the name of the report.
# 2. Sites: Select the required sites from the calendar.
# 3. Report recipients(s): Select the required recipients from the calendar.
# 4. Interval: Select the interval to generate the report from the drop-down.
#
# The available intervals are:
#
# 1. Instant: Allows the user to generate reports instantly.
# 2. Daily: Allows the user to generate a report daily.
# 3. Weekly: Allows the user to generate a report every week.
# 4. Monthly: Allows the user to generate a report every month.
# 5. Yearly: Allows the user to generate a report every year.
# 5. Start Date/ Time: Select the required start date and time from the calendar.
# 6. Events: Select the required event from the drop-down.
#
# 7. Chart Type: Select the required type of chart from the drop-down to represent the report. The available options are:
# 1. Chart: Allows the user to create a chart in the report.
# 2. Table: Allows the user to create a table in the report.
# 3. Click Submit .
#
# ## Generate Report
#
# The generate report in the Reports page option allows the user to generate the report for a specific period.
#
# Perform the following steps to generate a report:
#
# 1. Click against the respective report.
#
# <!-- image -->
#
# The Instant report duration pop-up appears.
#
# <!-- image -->
#
# Generate
#
# 2. Select the Start Date/Time and End Date/Time from the calendar.
#
# 3. Click Generate to generate the report .
#
# ## Edit Report
#
# The user can make changes to the report created using the edit option. Perform the following steps to edit a report:
#
# 1.
#
# Click against the respective report.
#
# <!-- image -->
#
# The Edit Report pop-up appears.
#
# <!-- image -->
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Report
#
# The user can remove the report from the list using the delete report option. Perform the following steps to delete a report:
#
# 1. Click against the respective report.
#
# <!-- image -->
#
# The following pop-up appears:
#
# <!-- image -->
#
# - i Do you want to delete this report?
# 2. Click Yes to delete the report or No to cancel.
#
# <!-- image -->
#
# The user can manage the display preferences of the Reports list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).
# - Click next to the column name to filter the list and display only the preferred items.
#
# - Use the pagination option
#
# to navigate
#
# between different sections of the list.
#
# - time.
#
# - Use the page size selector to choose the number of items displayed at a
#
# ## Gateways
#
# Gateways serve as an interface between a device and the local server. The function of the gateway is to facilitate communication between devices and collect information for processing, analysis, and monitoring. The Gateways page enables the user to add and manage the functioning of gateways.
#
# Click Gateways from the left panel. The following page appears:
#
# <!-- image -->
#
# The Gateways page displays the available gateways along with the basic details.
#
# Click on the gateway to learn more. The gateway dashboard appears.
#
# <!-- image -->
#
# The gateway dashboard displays a pictorial representation of the gateway along with the following information:
#
# - Status: Displays the current status of the gateway. The statuses displayed are:
# - Connected
# - Disconnected
# - Unknown
# - Platform: Displays the type of platform. The platforms are:
# - Managed: Displays when the organization manages the platform.
# - Unmanaged: Displays when the organization does not manage the platform.
# - Last Seen: Displays the date and time when the gateway is last connected.
# - Gateway Id: Displays the unique gateway id.
# - Installed In: Displays the name of the site connected along with the site image.
# - Events: Displays the number of events generated categorized as the following:
# - Critical
# - Major
# - Minor
#
# ## Add Gateway
#
# The Add Gateway option allows the user to add a new gateway. Perform the following steps to add a gateway:
#
# 1. Click Add Gateway on the Gateways page.
#
# <!-- image -->
#
# The Add Gateway pop-up appears
#
# <!-- image -->
#
# Submit
#
# 2. Fill in the following fields:
# 1. Name: Enter the name of the gateway.
# 2. Location: Select the required location from the drop-down.
# 3. Gateway Id: Enter the unique gateway id.
#
# - 4.
# - Heartbeat Interval: Select the time interval in which the gateway sends the statistics using the button.
# 5. Region: Select the required region from the drop-down.
# 3. Click Submit .
#
# ## Edit Gateway
#
# The user can make changes to the gateway details using the edit gateway option.
#
# Perform the following steps to edit a gateway:
#
# 1. Click on the gateway details.
#
# <!-- image -->
#
# ## The Edit gateway pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Gateway
#
# The Gateway page provides the option to remove a gateway using the delete option.
#
# Perform the following steps to delete a gateway:
#
# 1. Click on the gateway details.
#
# The following pop-up appears:
#
# - Are you sure you want to delete this gateway? Deleting the gateway will also remove all associated device connections.
#
# No
#
# Yes
#
# 2. Click Yes to delete the gateway or No to cancel.
#
# Use the following options to manage the content on the Gateway page:
#
# - Click Refresh to refresh the contents on the page.
# - Use the pagination option
# - between different sections of the list.
# - Use the page size selector to choose the number of items displayed at a time. 20
#
# to navigate
#
# ## Devices
#
# Devices are the sensors installed on various sites to monitor and notify the conditions of the sites.
#
# The Devices page allows the user to add and analyze the data from the devices at different sites.
#
# Click Devices from the left panel. The following page appears:
#
# <!-- image -->
#
# The Devices page displays the list of available devices with the following details:
#
# - Name: Displays the name of the device.
# - Status/Last Value: Displays the current value from the device.
# - Device Type: Displays the type of the device.
# - Battery: Displays the battery strength of the device.
# - Signal: Displays the signal strength of the device.
# - Location: Displays the site where the device is installed.
# - Last Seen: Displays the date and time when the device is last connected.
# - Action: Displays the actions available for the device. The actions are:
# - Edit
#
# <!-- image -->
#
# - Delete
#
# <!-- image -->
#
# Click to view the graphical representation of the device history. Hover over the graph to see the device status at a specific date and time.
#
# <!-- image -->
#
# ## Device Dashboard
#
# The device dashboard provides detailed information about the device. Click on the device name to view the dashboard.
#
# <!-- image -->
#
# The device dashboard displays the following information:
#
# - Device Information: Displays the device details such as:
# - DevUI: Displays the unique DevUI ID.
#
# Last seen: Displays the date and time when the device is last connected.
#
# - Battery Status: Displays the battery status of the device.
# - Signal Status: Displays the signal strength of the device.
# - Events: Displays the number of events generated on the device.
# - Current Status: Displays the current status according to the device property.
# - History: Displays the graphical representation of the device history.
#
# ## Add Device
#
# The Add Device option allows the user to add a device. Perform the following steps to add a new device:
#
# ## 1. Click Add Device on the Devices page.
#
# <!-- image -->
#
# ## The Add Device pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Fill in the following fields:
# 1. Name: Enter the name of the device.
# 2. Device Type: Select the required device type from the drop-down.
#
# 3. Sensor DevEUI: Enter the DevEUI obtained during the device purchase.
# 4. Application Key: Enter the application key obtained during the device purchase.
# 5. Location: Select the site to install the device from the drop-down.
# 6. Gateway: Select the required gateway from the drop-down.
# 7. Region: Select the required region from the drop-down.
# 8. Device Serial Number: Enter the serial number of the device, if required.
# 9. Description: Enter a description for the device.
# 3. Click Submit .
#
# ## Edit Device
#
# The user can make changes in the device details using the edit device option. Perform the following steps to edit a device:
#
# 1. Click against the respective device.
#
# <!-- image -->
#
# ## The Edit Device pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Device
#
# The user can remove a device from the list using the delete device option. Perform the following steps to delete a device:
#
# 1. Click against the respective device.
#
# <!-- image -->
#
# ## The following pop-up appears:
#
# <!-- image -->
#
# <!-- image -->
#
# 2. Enable the checkbox to delete all the events related to the device.
# 3. Click Yes to delete or No to cancel.
#
# The user can manage the display preferences of the Devices list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).
# - Click next to the column name to filter the list and display only the preferred items.
#
# - Use the pagination option to navigate between different sections of the list.
# - Use the page size selector to choose the number of items displayed at a time.
#
# ## Admin
#
# The Admin page provides an overview of key functionalities available within the application. The page shows various widgets that contain specific information and configuration options.
#
# Click Admin from the left panel. The following page appears:
#
# <!-- image -->
#
# The Admin page displays the following features:
#
# ## · Users
#
# - Active Users: Displays active users of the application. For more information, see Active UsersActive Users .
# - Invited Users: Displays registered users of the application. For more information, see Invited UsersInvited Users .
# - Add User: Allows the user to add a new user. For more information, see Add UserAdd User .
# - User Roles: Allows users to configure roles. For more information, see User RolesUser Roles .
# - Update Profile: Allows the user to update the profile details. For more information, see Update ProfileUpdate Profile .
#
# ## · Organization
#
# - Templates: Allows users to configure templates. For more information, see TemplatesTemplates .
# - Hierarchy: Allows users to configure hierarchy. For more information, see HierarchyHierarchy .
# - Account: Allows users to configure account details. For more information, see AccountAccount .
# - Site Locations: Allows the user to configure the site locations. For more information, see Site LocationsSite Locations .
# - Audit: Displays audit activities of the users. For more information, see AuditAudit .
#
# ## Invited Users
#
# The Invited Users page displays invited user information, where the users can view and manage relevant details.
#
# Click Invited Users from the Admin page. The following page appears:
#
# <!-- image -->
#
# The Invited Users page displays the following information:
#
# - Email: Displays the registered user's Email ID.
# - Role: Displays registered user's role.
# - State: Displays registered user's status.
# - Action: Displays available actions, which include:
# - Edit
# - Delete
# - Resend Activation Link
#
# <!-- image -->
#
# ## Add Invited User
#
# The Add User option in the Invited Users page allows the user to add an invited user.
#
# Perform the following steps to add an invited user:
#
# ## 1. Click Add User on the Active Users page.
#
# <!-- image -->
#
# The Add User pop-up appears.
#
# <!-- image -->
#
# ## 2. Fill in the following fields:
#
# 1. Email ID: Enter the registered user's Email ID.
# 2. Roles: Select the required role from the drop-down. The available roles are:
# - Account User
# - Account Admin
#
# ## 3. Click Submit .
#
# An activation link is sent to the user's email id. After the user account is activated via the link, the user is added to the active users list. For more information, see Active UsersActive Users .
#
# ## Edit Invited User
#
# The edit user option in the Invited Users page allows the user to edit the invited user details.
#
# Perform the following steps to edit a user:
#
# 1.
#
# <!-- image -->
#
# The Edit User pop-up appears.
#
# <!-- image -->
#
# 2. Edit the necessary fields and click Submit .
#
# ## Resend Activation Link
#
# The resend activation link option in the Invited Users page allows the user to send the activation link to the invited users.
#
# Perform the following steps to resend the activation link:
#
# 1. Click against the respective user.
#
# <!-- image -->
#
# The following pop-up appears:
#
# - Do want to re-send the activation link for this user? Please Confirm you
# 2. Click Yes to resend the activation link or click No to cancel.
#
# <!-- image -->
#
# ## Delete Invited User
#
# The delete user option in the Invited Users page allows the user to delete the user details.
#
# Perform the following steps to delete a user:
#
# 1. Click against the respective user.
#
# <!-- image -->
#
# ## The following pop-up appears:
#
# - 0 Do you want to delete this user?
#
# No
#
# Yes
#
# 2. Click Yes to delete the user.
#
# The user can manage the display preferences of the Invited Users list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t
# - Click next to the column name to filter the list and display only the preferred items.
# - Use the pagination option to navigate between different sections of the list.
# - Use the page size selector to choose the number of items displayed at a time. 20
#
# ## Active Users
#
# The Active Users page displays the details of the active users and allows the user to view and manage user details. The users invited or registered, receives an activation mail. Once the account is activated, the user is added to the active users list.
#
# Click Active Users from the Admin page. The following page appears:
#
# <!-- image -->
#
# The Active Users page displays the following fields:
#
# - First Name: Displays the first name of the active user.
# - Last Name: Displays the last name of the active user.
# - Email: Displays the email id of the active user.
# - Role: Displays the role of the active user.
# - Address: Displays the address of the active user.
# - Action: Displays the available actions such as:
# - Edit
# - •
# - Delete
# - Reset password
#
# ## Add Active User
#
# The Add User option in the Active Users page allows the user to add a new user.
#
# Perform the following steps to add a new user:
#
# 1. Click Add User on the Active Users page .
#
# <!-- image -->
#
# The Add User pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Fill in the following fields:
# 1. Email ID: Enter the registered user's Email ID.
# 2. Roles: Select the required role from the drop-down. The available roles are:
# - Account User
# - Account Admin
#
# ## 3. Click Submit .
#
# An activation link is sent to the user's email id. After the user account is activated via the link, the user is added to the active users list.
#
# ## Edit User
#
# The edit user option on the Active Users page allows users to edit the active user details.
#
# Perform the following steps to edit a user:
#
# 1.
#
# Click
#
# <!-- image -->
#
# against the respective user.
#
# ## The Edit User pop-up appears.
#
# Edit User
#
# <!-- image -->
#
# 2. Fill in the following fields:
# 1. Email ID: Enter the Email ID of the user.
# 2. First Name: Enter the user's first name.
# 3. Last Name: Enter the user's last name.
# 4. Address: Enter the user's address.
# 5. Phone Number: Enter the user's phone number.
# 6. Roles: Enter the user's role.
# 3. Click Submit .
#
# ## Delete Active User
#
# The delete user option in the Active Users page allows the user to delete the user details.
#
# Perform the following steps to delete a user:
#
# 1. Click against the respective user.
#
# <!-- image -->
#
# The following pop-up appears:
#
# - @ Do you want to delete this user?
# 2. Click Yes to delete the user. The user information is deleted.
#
# <!-- image -->
#
# ## Reset Password
#
# The reset password option in the Active Users page allows the user to Perform the following steps to reset the password:
#
# 1. Click against the respective user.
#
# <!-- image -->
#
# The Reset Password pop-up appears.
#
# <!-- image -->
#
# 2. Enter the new password in the following fields:
# 1. New Password
# 2. Confirm Password
# 3. Click Submit .
#
# The user can manage the display preferences of the Active Users list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t
#
# - Click items.
#
# - next to the column name to filter the list and display only the preferred
#
# - Use the pagination option to navigate between different sections of the list. 4
#
# - Use the page size selector to choose the number of items displayed at a time. 20
#
# ## Add User
#
# The Add User option allows the user to add a new user.
#
# Perform the following steps to add an invited user:
#
# 1. Click Add User on the Admin page.
#
# The Add User pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Provide the necessary information in the following fields:
# 1. Email ID: Enter the registered user's Email ID.
# 2. Roles: Select the required role from the drop-down.
# 3. Click Submit .
#
# An activation link is sent to the user's email id. After the user account is activated via the link, the user is added to the active users list. For more information, see Active UsersActive Users .
#
# ## User Roles
#
# The User Roles page allows the user to configure different roles. The admin configures the roles and provides the users with permissions to various functions.
#
# Click User Roles on the Admin page. The following page appears:
#
# <!-- image -->
#
# The User Roles page displays the following information:
#
# - Role Name: Displays the name of the user role.
# - Role Type: Displays the type of user role. The application selects System as the default role type.
# - Action: Displays the available actions. The actions are:
# - Edit
# - Delete
#
# ## Add User Role
#
# The Add Role option in the User Roles page allows the user to add a user role.
#
# Perform the following steps to add a user role:
#
# 1. Click Add Role on the User Roles page.
#
# <!-- image -->
#
# The Add Role pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Provide the necessary information in the following fields:
# 1. Role name: Enter the name of the user role.
#
# 2. Role Permissions: Select the required checkboxes against the required functionalities to provide permissions.
# 1. Select All -Select this checkbox to grant access to all functionalities.
# 3. Click Submit .
#
# ## Edit User Role
#
# The edit user role option in the User Roles page allows the user to edit a user role.
#
# Perform the following steps to edit a user role:
#
# <!-- image -->
#
# The Edit Role pop-up appears.
#
# Edit Role
#
# <!-- image -->
#
# Submit
#
# 2. Edit the necessary information in the required fields.
# 3. Click Submit .
#
# ## Delete User Role
#
# The delete user role option in the User Roles page allows the user to delete a user role.
#
# Perform the following steps to delete a user:
#
# 1. Click against the respective user role.
#
# <!-- image -->
#
# The following pop-up appears:
#
# - 0 Do you want to delete this role?
# 2. Click Yes to delete the user role or No to cancel.
#
# <!-- image -->
#
# The user can manage the display preferences of the User roles list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).
# - Click next to the column name to filter the list and display only the preferred items.
# - Use the pagination
#
# <!-- image -->
#
# between different sections of the list.
#
# - time.
#
# - Use the page size selector to choose the number of items displayed at a
#
# ## Update Profile
#
# The Update Profile option allows the user to edit the profile details.
#
# Click Update Profile on the Admin page. The following pop-up appears:
#
# Update Profile
#
# <!-- image -->
#
# Perform the following steps to update the profile:
#
# 1. Click Choose profile image to navigate to the user's folder and select a profile image.
# 2. Edit the following fields:
# 1. First Name: Enter the user's first name.
# 2. Last Name: Enter the user's last name.
# 3. Phone Number: Enter the user's phone number.
# 4. Address: Enter the user's address.
#
# 3. Enable the Email Notification and SMS Notification buttons to receive notifications.
# 4. Click Submit .
#
# ## Templates
#
# The Templates page allows the users to manage and configure the templates of the organization on the Hierarchy page.
#
# Click Templates on the Admin page. The following page appears:
#
# <!-- image -->
#
# The Templates page displays the following information about a template:
#
# - Template: Displays the type of template.
# - Description: Displays the description of the template
# - Action: Displays the available actions. The actions are:
# - Edit
# - Delete X
# - Configure
#
# ## Add Template
#
# The add template option in the Template page allows the user to add a new template.
#
# Perform the following steps to add a new template:
#
# <!-- image -->
#
# ## 1. Click Template on the Templates page.
#
# <!-- image -->
#
# The Add Template pop-up appears.
#
# <!-- image -->
#
# Submit
#
# ## 2. Fill in the following fields:
#
# 1. Name: Enter a template name.
# 2. Description: Enter a description for the template.
# 3. Template Icon: Click Choose Template Icon to select the template icon from the user's system.
# 4. Is it managed site: Select the checkbox if it is a managed site.
#
# 3. Click Submit .
#
# ## Edit Template
#
# The edit template option in the Template page allows the user to edit a template.
#
# Perform the following steps to edit a template:
#
# 1.
#
# <!-- image -->
#
# The Edit Template pop-up appears.
#
# <!-- image -->
#
# <!-- image -->
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Template
#
# The delete template option in the Template page allows the user to delete a template.
#
# Perform the following steps to delete a template.
#
# 1. Click against the respective template.
#
# <!-- image -->
#
# The following pop-up appears:
#
# - Do you want to delete this template?
#
# No
#
# Yes
#
# 2. Click Yes to delete the template or click No to cancel.
#
# ## Configure Template
#
# The configure template option in the Template page allows the user to configure a template:
#
# Perform the following steps to configure a template.
#
# 1.
#
# <!-- image -->
#
# ## The following page appears.
#
# <!-- image -->
#
# 2. Click Add Field to add the necessary fields.
#
# The Select Field Type pop-up appears.
#
# <!-- image -->
#
# Select Field Type
#
# <!-- image -->
#
# 3. Select the required field.
#
# The Add Field pop-up appears.
#
# Add Field
#
# Name
#
# Field required
#
# - [ ] Yes
#
# Submit
#
# <!-- image -->
#
# 4. Fill in the following fields:
# 1. Name -Enter a field name.
# 2. Field required - Select the Yes checkbox if the field is required.
# 5. Click Submit .
#
# ## Edit Field
#
# The edit field option in the template configuration page allows the user to edit a field in the template.
#
# Perform the following steps to edit a field:
#
# 1. Click against the required field on the template configuration page.
#
# <!-- image -->
#
# The Edit Field pop-up appears.
#
# <!-- image -->
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Field
#
# The delete field option in the template configuration page allows the user to delete a field in the template.
#
# Perform the following steps to delete a field:
#
# 1. Click against the required field on the template configuration page.
#
# <!-- image -->
#
# ## The following pop-up appears:
#
# - @ Do you want to delete this field?
# 2. Click Yes to delete the field or click No to cancel.
#
# <!-- image -->
#
# The user can manage the display preferences of the Templates list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t
# - Click next to the column name to filter the list and display only the preferred items.
# - Use the pagination option to navigate between different sections of the list. 2
# - Use the page size selector to choose the number of items displayed at a time. 20
#
# ## Hierarchy
#
# The Hierarchy page allows the user to create a hierarchy using the templates. The following are the available default templates:
#
# - Organization
# - State
# - Site
#
# Click Hierarchy on the Admin page. The following page appears:
#
# <!-- image -->
#
# The user can view the hierarchy generated using templates and associations on the Hierarchy page.
#
# ## Add Organization
#
# The Organization option in the Hierarchy page allows the users to add an organization template.
#
# Perform the following steps to add an organization:
#
# 1. Click Organization on the Hierarchy page.
#
# <!-- image -->
#
# ## The Add Organization pop-up appears.
#
# <!-- image -->
#
# 2. Fill in the following fields:
# 1. Name: Enter an organization name.
# 2. Description: Enter a description for the organization.
# 3. Click Submit. An entity corresponding to the organization is created on the Hierarchy page.
#
# ## Add State
#
# The State option in the Hierarchy page allows the user to add a state template.
#
# Perform the following steps to add a state:
#
# 1. Click State on the Hierarchy page.
#
# <!-- image -->
#
# ## The Add State pop-up appears.
#
# <!-- image -->
#
# 2. Fill in the following fields:
# 1. Name: Enter a state name.
# 2. Description: Enter a description for the state.
# 3. Click Submit. An entity corresponding to the state is created on the hierarchy page.
#
# ## Create Hierarchy
#
# The user can create a hierarchy by establishing associations between templates on the Hierarchy page.
#
# Perform the following steps to create a hierarchy:
#
# 1. Click Enable association mode .
# 2. Draw connections between the required entities. The hierarchy is created.
#
# <!-- image -->
#
# To add sites to the hierarchy, see Site LocationsSite Locations .
#
# ## Edit Template
#
# The edit option on the Hierarchy page allows the user to edit the template.
#
# Perform the following steps to edit a template:
#
# 1. On the Hierarchy page, right-click on the respective template.
#
# The following pop-up appears:
#
# <!-- image -->
#
# 2. Click Edit. The Edit Entity pop-up appears.
# 3. Edit the necessary fields and click Submit .
#
# <!-- image -->
#
# ## Delete Template
#
# The delete option on the Hierarchy page allows the user to delete the template.
#
# Perform the following steps to delete a template:
#
# 1. On the Hierarchy page, right-click on the template to delete.
#
# The following pop-up appears.
#
# <!-- image -->
#
# 2. Click Delete. A Confirmation pop-up appears.
#
# Confirmation
#
# <!-- image -->
#
# Are you sure you want to delete this entity?
#
# <!-- image -->
#
# 3. Click Yes to delete an entity or click No to cancel.
#
# ## Delete Association
#
# The delete association option in the Hierarchy page allows the user to delete the association.
#
# Perform the following steps to delete an association:
#
# 1. On the Hierarchy page, right-click on the respective association. A Confirmation pop-up appears.
# 2. Click Yes to delete the association or click No to cancel.
#
# <!-- image -->
#
# ## Account
#
# The Account page allows users to configure account details.
#
# Perform the following steps to customize the account:
#
# 1. Click Account on the Admin page. The Customize Account pop-up appears.
#
# Customize Account
#
# <!-- image -->
#
# Account Name
#
# Temperature Unit
#
# Demo
#
# - [ ] Celsius
#
# - [ ] Fahrenheit
#
# Save
#
# 2. Select the required checkbox against the Temperature Unit to set the temperature unit for the application and click Save .
#
# ## Site Locations
#
# The Site Locations page allows the user to create and manage the location of each site.
#
# Click Site Locations on the Admin page. The following page appears:
#
# <!-- image -->
#
# The Site Locations page displays the available sites and geographical locations.
#
# ## Add Site
#
# The Add Site option in the Site Locations page allows the user to add a site location.
#
# Perform the following steps to add a site:
#
# ## 1. Click Add Site on the Site Locations page.
#
# <!-- image -->
#
# The Add Site pop-up appears.
#
# <!-- image -->
#
# 2. Fill in the following fields:
# 1. Hierarchy: From the drop-down, select the required hierarchy.
# 2. Name: Enter the site name.
# 3. Description: Enter a description for the site.
# 4. Geographical Location: Enter the name of the location in the field or select from the map to choose the location.
# 5. Site image: Click Choose site Image to navigate to the user's file location and select the required site image.
# 3. Click Submit .
#
# ## Edit Site
#
# The Edit option in the Site Locations page allows the user to edit a site location
#
# Perform the following steps to edit a site location:
#
# <!-- image -->
#
# The Edit Site pop-up appears.
#
# <!-- image -->
#
# Submit
#
# 2. Edit the necessary fields and click Submit .
#
# ## Delete Site
#
# The delete site option in the Site Locations page allows the user to delete a site location.
#
# Perform the following steps to delete a site location:
#
# <!-- image -->
#
# The following pop-up appears:
#
# 2. Click Yes to delete the site location.
#
# The site location is deleted.
#
# ## Audit
#
# The Audit page displays the log of all the activity within the application. The Audit page also provides the relevant data of the activities done along with the date and time of the activity.
#
# Click Audit from the Admin page. The following page appears:
#
# <!-- image -->
#
# The Audit page displays the following fields:
#
# - Created Time: Displays the date and time of the activity.
# - Title: Displays the title of the activity.
# - Description: Displays the description of the activity.
#
# The user can manage the display preferences of the Audit list using the following options:
#
# - Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t
# - Click next to the column name to filter the list and display only the preferred items.
# - Use the pagination option to navigate between different sections of the list.
# - Use the page size selector to choose the number of items displayed at a time.
#
# ## Troubleshooting
#
# 1. Unable to log in to the ATT page:
# 1. Check Username and Password: Ensure the username and password are entered correctly.
# 2. Spelling: Verify that there are no typos in the username or password.
# 3. Ensure Caps Lock is Off: Check whether Caps Lock is inadvertently enabled.
# 4. Forgotten Password: If you can't remember the password, Reset Password "can't login" link on the login screen. You may be able to reset it via email.
# 5. Multiple Failed Login Attempts: After several unsuccessful login attempts, systems lock the account temporarily for security reasons. If this is the case, contact the service provider to unlock the account.
# 6. Browser Issues: If you're logging in via a web browser, try clearing your browser's cache, cookies, and history. Also, perform a hard refresh (Ctrl+Shift+R) Sometimes, old session data can prevent a successful login.
# 7. Browser Compatibility: If you're using a web browser and unable to log in, try switching to a different browser or use an incognito/private browsing mode.
# 8. Account Recovery: If none of the above step's work and you're still unable to log in, contact customer care via email- id: netvire.support@thinkpalm.com They may be able to assist with
# 10. account recovery or provide more specific troubleshooting for the service.
#
# ## 2. Gateway is down:
#
# 1. Check the gateway status is showing up or down in the gateway page also check the last seen of the gateway.
#
# 2. Check the validity of your SIM card to ensure your subscription hasn't expired. Confirm that your SIM's service is still active to avoid any disruptions.
#
# ## 3. Check Power and Connectivity:
#
# 1. Ensure the edge device is powered on and connected to the network.
# 2. Verify that all cables are securely connected and there are no loose connections.
# 4. LED Indicators: Check if the LED status lights on the gateway are steady.
# 5. Power Cycle: Unplug the gateway (modem), wait for 10 minutes then plug it back in. This can resolve many temporary issues.
# 6. If none of the above solutions work, please contact customer care via mail -id: netvire.support@thinkpalm.com .
#
# ## 3. Data not updating in the connected Devices:
#
# 1. Check the gateway is up or down in the gateway page.
# 2. Check the signal status and battery Health.
# 3. Check the device last updated time and date.
# 4. Check for any network outages or disruptions.
# 5. If the issue persists after troubleshooting, it may be a device-specific or firmware issue. Contact customer support for further assistance via mailid: netvire.support@thinkpalm.com. They will be able to provide firmware updates, advanced troubleshooting, or a hardware replacement.
#
# ## 4. Events not triggering in Events page:
#
# 1. Check the Gateway up or down.
# 2. Check the device status.
# 3. Check the Events rules settings to ensure it is configured to trigger the events. (make sure correct device is selected in the event rule condition).
# 4. Check that event repeat interval is blank if so, open event will not repeat.
# 5. Check if the threshold levels (temperature, humidity, CO2, etc.) are set correctly for triggering the alarm.
#
# 6. Ensure that there is no interference that could be disrupting the communication between the devices system and the dashboard (e.g., WiFi interference, physical obstructions).
# 7. Ensure that environmental conditions (like lighting or temperature) aren't preventing proper detection for sensor.
# 8. The alarm is still not triggering the dashboard, contact the customer support team via mail -id: netvire.support@thinkpalm.com .
#
# ## 5. Report Not Generating correctly:
#
# 1. Check the start end time of the report.
# 2. Verify that the devices or sensors are operational and transmitting data.
# 3. Check the filters or criteria set for the report. If the filters are too restrictive (e.g., an incorrect date range, specific sites, or user permissions), the report might fail to generate.
# 4. For instant report will only be generated for events occurring within the specified date range.
# 5. Review User Permissions to ensure the correct access rights for generating reports.
# 6. Clear Cache or Refresh the dashboard and test again.
# 7. If none of the above solutions work, please contact customer care via mail -id: netvire.support@thinkpalm.com .
#
# ## Maintenance
#
# - Check Sensor Placement for obstructions and correct positioning.
# - Clean the Sensors with a soft cloth or compressed air.
# - Inspect and Replace Batteries as needed.
# - Test Sensor Functionality by manually triggering the sensor and checking for response.
# - Update Firmware/Software to keep sensors running efficiently.
# - Check for Obstructions/Interference that could affect performance.Monitor Signal Strength (for wireless sensors) and eliminate any interference.
# - Inspect for Physical Wear and Tear or damage and replace faulty components.'

# %%
lc_docs
# Out:
# Document(metadata={}, page_content='## Introduction\n\nThe Smart Business IoT application allows the user to view and manage the data of various sensors installed on different sites. The user can monitor data focusing on light intensity, temperature, humidity, and carbon dioxide levels through installed devices. The application connects multiple sites and acts as a single data point. The user can add events, set event rules, generate reports based on the collected data, and manage administration through the application.\n\n## Login\n\nThe login page enables the user to access the Smart Business IoT application using the credentials. Once logged in, the user can navigate the application and explore the features.\n\nPerform the following steps to log in to Smart Business IoT:\n\n1. Launch any web browser and enter the application\'s URL to log in. The login page appears.\n2. Enter the Email address and Password in the respective fields.\n3. Click Login .\n\n<!-- image -->\n\n<!-- image -->\n\n## Reset Password\n\nThe user can recover the account through the Forgot your password? feature.\n\nTo reset the password, click Forgot your password? on the login page. The Reset your password section appears.\n\n<!-- image -->\n\n<!-- image -->\n\nEnter the email address associated with the account and click Send .\n\nA password reset link is sent to the registered email id. Follow the instructions in the mail to reset the password\n\n## Home\n\nHome is the landing page of the application. The Home page displays the location of the sites on the map. The following page appears when the user logs in:\n\n<!-- image -->\n\n<!-- image -->\n\nThe Home page represents each site location using the icon. The user can also find the number of alerts from the respective sites along with the icon. Click on the site location to access the site dashboard.\n\n## NetvirE Retail\n\nClick Sites to view the list of all sites. The Sites pop-up appears.\n\n<!-- image -->\n\nSearch for the required site from the list using the Search Site option.\n\nThe Sites pop-up displays the list of all sites along with the following information:\n\n- Number of devices installed on the sites.\n- Number of gateways connected to the sites.\n- Number of alarms generated on the site.\n\nThe user can view the site location on the map using the icon. Click View to navigate to the site dashboard. For more information, see Site DashboardSite Dashboard .\n\n## Site Dashboard\n\nThe site dashboard provides the user with the status, history, and statistics of the devices installed on the site. The user can access the site dashboard from the site location icon on the map or through the Sites pop-up. The site dashboard appears as follows:\n\n<!-- image -->\n\nThe site dashboard provides the user with the following options:\n\n- Status: Displays the current status of the devices installed on the site along with the last connected date and time.\n\n<!-- image -->\n\n- History: Displays the history of the devices installed on the site using graphical representations.\n\n<!-- image -->\n\nThe graph is plotted using the measured value of each device against time.\n\nHover over the graph to view the history at a given point of time.\n\n- Detail: Displays the statistics of the devices installed on the site along with the respective graphs.\n\n<!-- image -->\n\nThe Detail tab also provides the following information about the sites:\n\n- Number of active\n- and inactive\n\n<!-- image -->\n\ngateways.\n\n- Number of active and inactive devices.\n- Number of events generated on the site categorized as follows:\n- Critical\n- Major\n- Minor\n- Events\n- : Displays the number of events generated on the site.\n- Refresh: Allows the user to refresh the contents on the site dashboard.\n- Last updated: Displays the date and time when the data is last updated.\n- Name: Allows the user to filter the data based on the device name.\n- Type: Allows the user to filter the data based on the device type.\n- Dat ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter


text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

chunks = text_splitter.split_documents([lc_docs])

# %%
chunks
# Out:
# [Document(metadata={}, page_content="## Introduction\n\nThe Smart Business IoT application allows the user to view and manage the data of various sensors installed on different sites. The user can monitor data focusing on light intensity, temperature, humidity, and carbon dioxide levels through installed devices. The application connects multiple sites and acts as a single data point. The user can add events, set event rules, generate reports based on the collected data, and manage administration through the application.\n\n## Login\n\nThe login page enables the user to access the Smart Business IoT application using the credentials. Once logged in, the user can navigate the application and explore the features.\n\nPerform the following steps to log in to Smart Business IoT:\n\n1. Launch any web browser and enter the application's URL to log in. The login page appears.\n2. Enter the Email address and Password in the respective fields.\n3. Click Login .\n\n<!-- image -->\n\n<!-- image -->\n\n## Reset Password"),
#  Document(metadata={}, page_content='<!-- image -->\n\n<!-- image -->\n\n## Reset Password\n\nThe user can recover the account through the Forgot your password? feature.\n\nTo reset the password, click Forgot your password? on the login page. The Reset your password section appears.\n\n<!-- image -->\n\n<!-- image -->\n\nEnter the email address associated with the account and click Send .\n\nA password reset link is sent to the registered email id. Follow the instructions in the mail to reset the password\n\n## Home\n\nHome is the landing page of the application. The Home page displays the location of the sites on the map. The following page appears when the user logs in:\n\n<!-- image -->\n\n<!-- image -->\n\nThe Home page represents each site location using the icon. The user can also find the number of alerts from the respective sites along with the icon. Click on the site location to access the site dashboard.\n\n## NetvirE Retail\n\nClick Sites to view the list of all sites. The Sites pop-up appears.\n\n<!-- image -->'),
#  Document(metadata={}, page_content='Click Sites to view the list of all sites. The Sites pop-up appears.\n\n<!-- image -->\n\nSearch for the required site from the list using the Search Site option.\n\nThe Sites pop-up displays the list of all sites along with the following information:\n\n- Number of devices installed on the sites.\n- Number of gateways connected to the sites.\n- Number of alarms generated on the site.\n\nThe user can view the site location on the map using the icon. Click View to navigate to the site dashboard. For more information, see Site DashboardSite Dashboard .\n\n## Site Dashboard\n\nThe site dashboard provides the user with the status, history, and statistics of the devices installed on the site. The user can access the site dashboard from the site location icon on the map or through the Sites pop-up. The site dashboard appears as follows:\n\n<!-- image -->\n\nThe site dashboard provides the user with the following options:'),
#  Document(metadata={}, page_content='<!-- image -->\n\nThe site dashboard provides the user with the following options:\n\n- Status: Displays the current status of the devices installed on the site along with the last connected date and time.\n\n<!-- image -->\n\n- History: Displays the history of the devices installed on the site using graphical representations.\n\n<!-- image -->\n\nThe graph is plotted using the measured value of each device against time.\n\nHover over the graph to view the history at a given point of time.\n\n- Detail: Displays the statistics of the devices installed on the site along with the respective graphs.\n\n<!-- image -->\n\nThe Detail tab also provides the following information about the sites:\n\n- Number of active\n- and inactive\n\n<!-- image -->\n\ngateways.'),
#  Document(metadata={}, page_content='- Number of active\n- and inactive\n\n<!-- image -->\n\ngateways.\n\n- Number of active and inactive devices.\n- Number of events generated on the site categorized as follows:\n- Critical\n- Major\n- Minor\n- Events\n- : Displays the number of events generated on the site.\n- Refresh: Allows the user to refresh the contents on the site dashboard.\n- Last updated: Displays the date and time when the data is last updated.\n- Name: Allows the user to filter the data based on the device name.\n- Type: Allows the user to filter the data based on the device type.\n- Date filter: Allows the user to filter the data based on predefined time intervals. The information displayed on the page is set to display data from the Past 1 day by default.\n\n<!-- image -->\n\n<!-- image -->\n\nThe application also provides the option to view data within a custom range filter according to user preference. Click Custom range from the drop-down and select the required date and time range from the Select date range calendar.'),
#  Document(metadata={}, page_content='Note: The Custom range filter appears only when the user opens the History and Detail tab.\n\n## Dashboard\n\nThe Dashboard provides users with information about the devices installed at all locations. Users can view the status, history, and statistics of each device on the sites. Click Dashboard from the left panel. The following page appears:\n\n<!-- image -->\n\nThe Dashboard provides the user with the following options:\n\n- Status: Displays the current status of the devices installed along with the last connected date and time. Click on the site icon on the device information to go to the site dashboard.\n\nNetvirE Retail\n\n<!-- image -->\n\nTo change the layout of the dashboard, drag the sensor information to the required position and click Save. The Save button appears only when the user changes the layout. Click Reset to reset the previous layout.\n\n- History: Displays the history of the devices installed using graphical representations.\n\n<!-- image -->'),
#  Document(metadata={}, page_content='<!-- image -->\n\nThe graph is plotted using the measured value of each device against time. Hover over the graph to view the history at a given point of time.\n\n- Detail: Displays the statistics of the devices installed along with the respective graphs.\n\n## NetvirE Retail\n\n<!-- image -->\n\nThe Detail tab also provides the following information:\n\n- Number of active\n- •\n- and inactive\n- Number of active and inactive\n\ngateways.\n\ndevices.\n\n<!-- image -->\n\n<!-- image -->'),
#  Document(metadata={}, page_content='gateways.\n\ndevices.\n\n<!-- image -->\n\n<!-- image -->\n\n- Number of events generated on the site categorized as follows:\n- Critical\n- Major\n- Minor\n- Events\n- : Displays the number of events generated.\n- Refresh: Allows the user to refresh the contents on the dashboard.\n- Last updated: Displays the date and time when the data is last updated.\n- Name: Allows the user to filter the data based on the device name.\n- Type: Allows the user to filter the data based on the device type.\n- Date filter: Allows the user to filter the data based on predefined time intervals.\n- The information displayed on the page is set to display data from the Past 1 day by default.\n\n<!-- image -->\n\nThe application also provides the option to view data within a custom range filter according to user preference. Click Custom range from the drop-down and select the required date and time range from the Select date range calendar.'),
#  Document(metadata={}, page_content='Note: The Custom range filter appears only when the user opens the History and Detail tab.\n\n## Events\n\nAn event is triggered when the data from the sensor meets certain predefined conditions or rules. The users are notified using an alarm whenever an alarm occurs.\n\nThe Events page monitors and keeps track of the events generated on the sites. The user can manage and view the event list on the Events page.\n\nClick Events from the left panel. The following page appears:\n\n<!-- image -->\n\nThe Events page provides the following information:\n\n- Events: Displays the number of events generated categorized as follows:\n- Critical\n- Major\n- Minor\n- Click Event Rules to add an event rule. For more information, see Event RulesEvent Rules. Use the Refresh button to refresh the information on the page.\n- Last 7 Days Event Status: Displays the graphical representation of the event statuses from the last 7 days. The event statuses are categorized into the following:\n- Unresolved\n\n## · Resolved'),
#  Document(metadata={}, page_content='## · Resolved\n\n- Event list: Displays the list of events generated with the following fields:\n- Created At: Displays the date and time of the event generation.\n- Event: Displays the title of the event.\n- Device/ Gateway Name: Displays the device or gateway where the event is generated.\n- Severity: Displays the severity of the event.\n- Event State: Displays the state of the event.\n- Action: Displays the actions available on the event. The actions are:\n- Acknowledge\n- Clear\n\n## Acknowledge Event\n\nThe acknowledge event option allows the user to mark an event as acknowledged for further actions.\n\nPerform the following steps to acknowledge an event:\n\n1. Click against the respective event.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n<!-- image -->\n\n- Do you want to acknowledge this event?\n2. Click Yes to acknowledge the event or No to cancel.\n\n<!-- image -->\n\nTo acknowledge multiple events, select the required events and click the Acknowledge button at the top of the event list.'),
#  Document(metadata={}, page_content='## Clear Event\n\nThe clear event option allows the user to mark an event as closed.\n\nPerform the following steps to clear an event:\n\n1. Click against the respective event.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n- Do you want to clear this event?\n2. Click Yes to clear the event or No to cancel.\n\n<!-- image -->\n\nTo clear multiple events, select the required events and click Clear at the top of the event list.\n\nThe user can manage the display preferences of the events list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).\n- Click next to the column name to filter the list and display only the preferred items.\n- Use the pagination option to navigate between different sections of the list.\n- Use the page size selector to choose the number of items displayed at a time.\n\n## Event Rules'),
#  Document(metadata={}, page_content='## Event Rules\n\nEvent Rules are a set of user -defined conditions that detect events when the sensor data meets the conditions and triggers a corresponding action. The Event Rules page enables the user to create and manage event rules.\n\nClick Event Rules from the Events page. The following page appears:\n\n<!-- image -->\n\nThe Event Rules page displays the list of event rules created with the following fields:\n\n- Rule: Displays the title of the event rule.\n- Action: Displays the action corresponding to the rule.\n- Users: Displays the users to notify during the event.\n- State: Displays the current state of the rule.\n- Edit\n- Delete\n\n<!-- image -->\n\n<!-- image -->\n\nClick to view the history of the event rule. The events generated from the particular rule appear as follows:\n\n<!-- image -->\n\n- Click to acknowledge the event. For more information, see Acknowledge EvenAcknowledge Event .\n- Click to clear the event. For more information, see Clear EventClear Event .\n\n## Add Event Rule'),
#  Document(metadata={}, page_content='## Add Event Rule\n\nThe Add Event Rule option allows the user to create an event rule. Perform the following steps to add a new event rule:\n\n1. Click Add Event Rule on the Event Rules page.\n\n<!-- image -->\n\n## The Add event rule pop-up appears.\n\n<!-- image -->\n\nCancel\n\n<!-- image -->\n\n## 2. Fill in the following fields:\n\n- a. Rule: Enter the title of the rule.'),
#  Document(metadata={}, page_content='- b. Add Condition: Click Add Condition to add the rule. The following fields appear:\n- i. Merge Condition: The Merge Condition field is enabled only when at least one condition is added. Select the required option from the drop-down to merge the conditions.\n- ii. Gateway/Device: Select the required option from the Gateway/Device drop-down.\n1. Gateway: Allows the user to define the event rule based on the gateways.\n2. Device: Allows the user to define the event rule based on the devices.\n- iii. Filter by: Select the required filter option from the drop-down.\n7. For the Gateway option, the following filter options appear:\n1. Any: Allows the user to select all the devices.\n2. Gateway: Allows the user to select a specific gateway.\n- iv. For the Device option, the following filter options appear:\n1. Any: Allows the user to select all the devices.\n2. Device type: Allows the user to select a device of a specific type.\n3. Device name: Allows the user to select a specific device.'),
#  Document(metadata={}, page_content='3. Device name: Allows the user to select a specific device.\n- v. Property: Select the required property from the drop-down.\n- vi. Operator: Select the required operator from the drop-down.'),
#  Document(metadata={}, page_content='<!-- image -->\n\n- vii. Value: Enter the required threshold value.\n\n- viii. Time Period: Select the required time period option from the drop- down. The available options are:\n\n1. N/A: Select N/A if time period is not applicable.\n\n2. Duration: Allows the user to specify a particular time duration. Enter the required time duration in the Time field that appears below.\n\n3. Interval: Allows the user to select a time interval. Select the required interval from the Start Time and End Time fields that appear below.\n\n- ix. Click Add to submit the condition or Cancel to clear the condition.\n\n- c. Event: Enter the event description. Click\n\nto view and select the\n\n- dynamic fields. Copy and paste the required options in the field. The application replaces the fields with actual values.\n\n- d. Severity: Select the severity of the event from the drop-down. The available options are:\n\n- i. Major\n\n- ii. Minor\n\n- iii. Critical\n\n- e. Notes: Enter the comments or notes, if any. Click'),
#  Document(metadata={}, page_content='- i. Major\n\n- ii. Minor\n\n- iii. Critical\n\n- e. Notes: Enter the comments or notes, if any. Click\n\n- [ ] to view and select\n\nthe dynamic fields. Copy\n\nand paste the required options in the field.\n\nThe application replaces the fields with actual values.\n\n- f. Event Report Filter: Enter the threshold time interval to detect the events to avoid repeated triggers.\n\n- g. Event Action Type: Select the required event action type from the drop- down. The available actions are:\n\n- i. SMS: The SMS Text field appears when the user selects the SMS option in the Event Action Type field. Enter the message required\n\n## to send to the recipients.\n\n<!-- image -->\n\n<!-- image -->\n\nClick to view and select the dynamic fields. Copy and paste the required options in the field. The application replaces the fields with actual values.\n\n- h. Event Recipient(s): Select the users to notify during the event from the drop-down.\n3. Select the Enable checkbox to enable the rule and click Submit .'),
#  Document(metadata={}, page_content='## Edit Event Rule\n\nThe application enables users to update and manage the existing rules using the edit option. Perform the following steps to edit a rule:\n\n1.\n\nClick against the respective event rule.\n\n<!-- image -->\n\n## The Edit event rule pop-up appears.\n\n<!-- image -->\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Event Rule\n\nThe delete option allows the user to remove an event rule. Perform the following steps to delete an event rule:\n\n1. Click against the respective event rule.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n- Do you want to delete this rule?\n2. Click Yes to delete the rule or No to cancel.\n\n<!-- image -->\n\nThe user can manage the display preferences of the Event Rules list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).\n- Click next to the column name to filter the list and display only the preferred items.\n- Use the pagination\n\n<!-- image -->\n\nto\n\n<!-- image -->'),
#  Document(metadata={}, page_content='<!-- image -->\n\nto\n\n<!-- image -->\n\n- Use the page size selector displayed at a time.\n\nto choose the number of items\n\n## Reports\n\nReports help the users to track and analyze the events generated on the sites. The Reports page on the application enables the user to create and manage reports using table and chart representation.\n\nClick Reports on the left panel. The Reports page appears as follows:\n\n<!-- image -->\n\nThe Reports page displays the list of reports created with the following fields:\n\n- Report Name: Displays the name of the report.\n- Interval: Displays the selected time interval for report generation.\n- Report Type: Displays the type of the report generated.\n- Action: Displays the action available for the report. The actions are:\n- Generate report\n- Edit report\n- Delete report\n\nClick to view the history of the report. The details of the generated report appear here.\n\n## NetvirE Retail\n\nClick Download to download the report and\n\n<!-- image -->\n\n## Add Report'),
#  Document(metadata={}, page_content='## NetvirE Retail\n\nClick Download to download the report and\n\n<!-- image -->\n\n## Add Report\n\nThe Add Report option allows the user to add a new report.\n\nPerform the following steps to add a report:\n\n1. Click Add Report on the Reports page.\n\nto delete the report.\n\n<!-- image -->\n\n## The Add Report pop-up appears.\n\n## Add Report\n\n<!-- image -->\n\nSubmit\n\n## 2. Fill in the following fields:\n\n1. Report Name: Enter the name of the report.\n2. Sites: Select the required sites from the calendar.\n3. Report recipients(s): Select the required recipients from the calendar.\n4. Interval: Select the interval to generate the report from the drop-down.\n\nThe available intervals are:'),
#  Document(metadata={}, page_content='The available intervals are:\n\n1. Instant: Allows the user to generate reports instantly.\n2. Daily: Allows the user to generate a report daily.\n3. Weekly: Allows the user to generate a report every week.\n4. Monthly: Allows the user to generate a report every month.\n5. Yearly: Allows the user to generate a report every year.\n5. Start Date/ Time: Select the required start date and time from the calendar.\n6. Events: Select the required event from the drop-down.\n\n7. Chart Type: Select the required type of chart from the drop-down to represent the report. The available options are:\n1. Chart: Allows the user to create a chart in the report.\n2. Table: Allows the user to create a table in the report.\n3. Click Submit .\n\n## Generate Report\n\nThe generate report in the Reports page option allows the user to generate the report for a specific period.\n\nPerform the following steps to generate a report:\n\n1. Click against the respective report.\n\n<!-- image -->'),
#  Document(metadata={}, page_content='1. Click against the respective report.\n\n<!-- image -->\n\nThe Instant report duration pop-up appears.\n\n<!-- image -->\n\nGenerate\n\n2. Select the Start Date/Time and End Date/Time from the calendar.\n\n3. Click Generate to generate the report .\n\n## Edit Report\n\nThe user can make changes to the report created using the edit option. Perform the following steps to edit a report:\n\n1.\n\nClick against the respective report.\n\n<!-- image -->\n\nThe Edit Report pop-up appears.\n\n<!-- image -->\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Report\n\nThe user can remove the report from the list using the delete report option. Perform the following steps to delete a report:\n\n1. Click against the respective report.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n<!-- image -->\n\n- i Do you want to delete this report?\n2. Click Yes to delete the report or No to cancel.\n\n<!-- image -->\n\nThe user can manage the display preferences of the Reports list using the following options:'),
#  Document(metadata={}, page_content='The user can manage the display preferences of the Reports list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).\n- Click next to the column name to filter the list and display only the preferred items.\n\n- Use the pagination option\n\nto navigate\n\nbetween different sections of the list.\n\n- time.\n\n- Use the page size selector to choose the number of items displayed at a\n\n## Gateways\n\nGateways serve as an interface between a device and the local server. The function of the gateway is to facilitate communication between devices and collect information for processing, analysis, and monitoring. The Gateways page enables the user to add and manage the functioning of gateways.\n\nClick Gateways from the left panel. The following page appears:\n\n<!-- image -->\n\nThe Gateways page displays the available gateways along with the basic details.\n\nClick on the gateway to learn more. The gateway dashboard appears.'),
#  Document(metadata={}, page_content='Click on the gateway to learn more. The gateway dashboard appears.\n\n<!-- image -->\n\nThe gateway dashboard displays a pictorial representation of the gateway along with the following information:\n\n- Status: Displays the current status of the gateway. The statuses displayed are:\n- Connected\n- Disconnected\n- Unknown\n- Platform: Displays the type of platform. The platforms are:\n- Managed: Displays when the organization manages the platform.\n- Unmanaged: Displays when the organization does not manage the platform.\n- Last Seen: Displays the date and time when the gateway is last connected.\n- Gateway Id: Displays the unique gateway id.\n- Installed In: Displays the name of the site connected along with the site image.\n- Events: Displays the number of events generated categorized as the following:\n- Critical\n- Major\n- Minor\n\n## Add Gateway\n\nThe Add Gateway option allows the user to add a new gateway. Perform the following steps to add a gateway:\n\n1. Click Add Gateway on the Gateways page.'),
#  Document(metadata={}, page_content='1. Click Add Gateway on the Gateways page.\n\n<!-- image -->\n\nThe Add Gateway pop-up appears\n\n<!-- image -->\n\nSubmit\n\n2. Fill in the following fields:\n1. Name: Enter the name of the gateway.\n2. Location: Select the required location from the drop-down.\n3. Gateway Id: Enter the unique gateway id.\n\n- 4.\n- Heartbeat Interval: Select the time interval in which the gateway sends the statistics using the button.\n5. Region: Select the required region from the drop-down.\n3. Click Submit .\n\n## Edit Gateway\n\nThe user can make changes to the gateway details using the edit gateway option.\n\nPerform the following steps to edit a gateway:\n\n1. Click on the gateway details.\n\n<!-- image -->\n\n## The Edit gateway pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Gateway\n\nThe Gateway page provides the option to remove a gateway using the delete option.\n\nPerform the following steps to delete a gateway:\n\n1. Click on the gateway details.'),
#  Document(metadata={}, page_content='Perform the following steps to delete a gateway:\n\n1. Click on the gateway details.\n\nThe following pop-up appears:\n\n- Are you sure you want to delete this gateway? Deleting the gateway will also remove all associated device connections.\n\nNo\n\nYes\n\n2. Click Yes to delete the gateway or No to cancel.\n\nUse the following options to manage the content on the Gateway page:\n\n- Click Refresh to refresh the contents on the page.\n- Use the pagination option\n- between different sections of the list.\n- Use the page size selector to choose the number of items displayed at a time. 20\n\nto navigate\n\n## Devices\n\nDevices are the sensors installed on various sites to monitor and notify the conditions of the sites.\n\nThe Devices page allows the user to add and analyze the data from the devices at different sites.\n\nClick Devices from the left panel. The following page appears:\n\n<!-- image -->\n\nThe Devices page displays the list of available devices with the following details:'),
#  Document(metadata={}, page_content='The Devices page displays the list of available devices with the following details:\n\n- Name: Displays the name of the device.\n- Status/Last Value: Displays the current value from the device.\n- Device Type: Displays the type of the device.\n- Battery: Displays the battery strength of the device.\n- Signal: Displays the signal strength of the device.\n- Location: Displays the site where the device is installed.\n- Last Seen: Displays the date and time when the device is last connected.\n- Action: Displays the actions available for the device. The actions are:\n- Edit\n\n<!-- image -->\n\n- Delete\n\n<!-- image -->\n\nClick to view the graphical representation of the device history. Hover over the graph to see the device status at a specific date and time.\n\n<!-- image -->\n\n## Device Dashboard\n\nThe device dashboard provides detailed information about the device. Click on the device name to view the dashboard.\n\n<!-- image -->\n\nThe device dashboard displays the following information:'),
#  Document(metadata={}, page_content='<!-- image -->\n\nThe device dashboard displays the following information:\n\n- Device Information: Displays the device details such as:\n- DevUI: Displays the unique DevUI ID.\n\nLast seen: Displays the date and time when the device is last connected.\n\n- Battery Status: Displays the battery status of the device.\n- Signal Status: Displays the signal strength of the device.\n- Events: Displays the number of events generated on the device.\n- Current Status: Displays the current status according to the device property.\n- History: Displays the graphical representation of the device history.\n\n## Add Device\n\nThe Add Device option allows the user to add a device. Perform the following steps to add a new device:\n\n## 1. Click Add Device on the Devices page.\n\n<!-- image -->\n\n## The Add Device pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Fill in the following fields:\n1. Name: Enter the name of the device.\n2. Device Type: Select the required device type from the drop-down.'),
#  Document(metadata={}, page_content='3. Sensor DevEUI: Enter the DevEUI obtained during the device purchase.\n4. Application Key: Enter the application key obtained during the device purchase.\n5. Location: Select the site to install the device from the drop-down.\n6. Gateway: Select the required gateway from the drop-down.\n7. Region: Select the required region from the drop-down.\n8. Device Serial Number: Enter the serial number of the device, if required.\n9. Description: Enter a description for the device.\n3. Click Submit .\n\n## Edit Device\n\nThe user can make changes in the device details using the edit device option. Perform the following steps to edit a device:\n\n1. Click against the respective device.\n\n<!-- image -->\n\n## The Edit Device pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Device\n\nThe user can remove a device from the list using the delete device option. Perform the following steps to delete a device:\n\n1. Click against the respective device.\n\n<!-- image -->'),
#  Document(metadata={}, page_content='1. Click against the respective device.\n\n<!-- image -->\n\n## The following pop-up appears:\n\n<!-- image -->\n\n<!-- image -->\n\n2. Enable the checkbox to delete all the events related to the device.\n3. Click Yes to delete or No to cancel.\n\nThe user can manage the display preferences of the Devices list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).\n- Click next to the column name to filter the list and display only the preferred items.\n\n- Use the pagination option to navigate between different sections of the list.\n- Use the page size selector to choose the number of items displayed at a time.\n\n## Admin\n\nThe Admin page provides an overview of key functionalities available within the application. The page shows various widgets that contain specific information and configuration options.\n\nClick Admin from the left panel. The following page appears:\n\n<!-- image -->'),
#  Document(metadata={}, page_content='Click Admin from the left panel. The following page appears:\n\n<!-- image -->\n\nThe Admin page displays the following features:\n\n## · Users\n\n- Active Users: Displays active users of the application. For more information, see Active UsersActive Users .\n- Invited Users: Displays registered users of the application. For more information, see Invited UsersInvited Users .\n- Add User: Allows the user to add a new user. For more information, see Add UserAdd User .\n- User Roles: Allows users to configure roles. For more information, see User RolesUser Roles .\n- Update Profile: Allows the user to update the profile details. For more information, see Update ProfileUpdate Profile .\n\n## · Organization'),
#  Document(metadata={}, page_content='## · Organization\n\n- Templates: Allows users to configure templates. For more information, see TemplatesTemplates .\n- Hierarchy: Allows users to configure hierarchy. For more information, see HierarchyHierarchy .\n- Account: Allows users to configure account details. For more information, see AccountAccount .\n- Site Locations: Allows the user to configure the site locations. For more information, see Site LocationsSite Locations .\n- Audit: Displays audit activities of the users. For more information, see AuditAudit .\n\n## Invited Users\n\nThe Invited Users page displays invited user information, where the users can view and manage relevant details.\n\nClick Invited Users from the Admin page. The following page appears:\n\n<!-- image -->\n\nThe Invited Users page displays the following information:'),
#  Document(metadata={}, page_content="<!-- image -->\n\nThe Invited Users page displays the following information:\n\n- Email: Displays the registered user's Email ID.\n- Role: Displays registered user's role.\n- State: Displays registered user's status.\n- Action: Displays available actions, which include:\n- Edit\n- Delete\n- Resend Activation Link\n\n<!-- image -->\n\n## Add Invited User\n\nThe Add User option in the Invited Users page allows the user to add an invited user.\n\nPerform the following steps to add an invited user:\n\n## 1. Click Add User on the Active Users page.\n\n<!-- image -->\n\nThe Add User pop-up appears.\n\n<!-- image -->\n\n## 2. Fill in the following fields:\n\n1. Email ID: Enter the registered user's Email ID.\n2. Roles: Select the required role from the drop-down. The available roles are:\n- Account User\n- Account Admin\n\n## 3. Click Submit ."),
#  Document(metadata={}, page_content="## 3. Click Submit .\n\nAn activation link is sent to the user's email id. After the user account is activated via the link, the user is added to the active users list. For more information, see Active UsersActive Users .\n\n## Edit Invited User\n\nThe edit user option in the Invited Users page allows the user to edit the invited user details.\n\nPerform the following steps to edit a user:\n\n1.\n\n<!-- image -->\n\nThe Edit User pop-up appears.\n\n<!-- image -->\n\n2. Edit the necessary fields and click Submit .\n\n## Resend Activation Link\n\nThe resend activation link option in the Invited Users page allows the user to send the activation link to the invited users.\n\nPerform the following steps to resend the activation link:\n\n1. Click against the respective user.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n- Do want to re-send the activation link for this user? Please Confirm you\n2. Click Yes to resend the activation link or click No to cancel.\n\n<!-- image -->\n\n## Delete Invited User"),
#  Document(metadata={}, page_content='<!-- image -->\n\n## Delete Invited User\n\nThe delete user option in the Invited Users page allows the user to delete the user details.\n\nPerform the following steps to delete a user:\n\n1. Click against the respective user.\n\n<!-- image -->\n\n## The following pop-up appears:\n\n- 0 Do you want to delete this user?\n\nNo\n\nYes\n\n2. Click Yes to delete the user.\n\nThe user can manage the display preferences of the Invited Users list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t\n- Click next to the column name to filter the list and display only the preferred items.\n- Use the pagination option to navigate between different sections of the list.\n- Use the page size selector to choose the number of items displayed at a time. 20\n\n## Active Users'),
#  Document(metadata={}, page_content='## Active Users\n\nThe Active Users page displays the details of the active users and allows the user to view and manage user details. The users invited or registered, receives an activation mail. Once the account is activated, the user is added to the active users list.\n\nClick Active Users from the Admin page. The following page appears:\n\n<!-- image -->\n\nThe Active Users page displays the following fields:\n\n- First Name: Displays the first name of the active user.\n- Last Name: Displays the last name of the active user.\n- Email: Displays the email id of the active user.\n- Role: Displays the role of the active user.\n- Address: Displays the address of the active user.\n- Action: Displays the available actions such as:\n- Edit\n- •\n- Delete\n- Reset password\n\n## Add Active User\n\nThe Add User option in the Active Users page allows the user to add a new user.\n\nPerform the following steps to add a new user:\n\n1. Click Add User on the Active Users page .\n\n<!-- image -->'),
#  Document(metadata={}, page_content="1. Click Add User on the Active Users page .\n\n<!-- image -->\n\nThe Add User pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Fill in the following fields:\n1. Email ID: Enter the registered user's Email ID.\n2. Roles: Select the required role from the drop-down. The available roles are:\n- Account User\n- Account Admin\n\n## 3. Click Submit .\n\nAn activation link is sent to the user's email id. After the user account is activated via the link, the user is added to the active users list.\n\n## Edit User\n\nThe edit user option on the Active Users page allows users to edit the active user details.\n\nPerform the following steps to edit a user:\n\n1.\n\nClick\n\n<!-- image -->\n\nagainst the respective user.\n\n## The Edit User pop-up appears.\n\nEdit User\n\n<!-- image -->"),
#  Document(metadata={}, page_content="against the respective user.\n\n## The Edit User pop-up appears.\n\nEdit User\n\n<!-- image -->\n\n2. Fill in the following fields:\n1. Email ID: Enter the Email ID of the user.\n2. First Name: Enter the user's first name.\n3. Last Name: Enter the user's last name.\n4. Address: Enter the user's address.\n5. Phone Number: Enter the user's phone number.\n6. Roles: Enter the user's role.\n3. Click Submit .\n\n## Delete Active User\n\nThe delete user option in the Active Users page allows the user to delete the user details.\n\nPerform the following steps to delete a user:\n\n1. Click against the respective user.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n- @ Do you want to delete this user?\n2. Click Yes to delete the user. The user information is deleted.\n\n<!-- image -->\n\n## Reset Password\n\nThe reset password option in the Active Users page allows the user to Perform the following steps to reset the password:\n\n1. Click against the respective user.\n\n<!-- image -->\n\nThe Reset Password pop-up appears."),
#  Document(metadata={}, page_content='1. Click against the respective user.\n\n<!-- image -->\n\nThe Reset Password pop-up appears.\n\n<!-- image -->\n\n2. Enter the new password in the following fields:\n1. New Password\n2. Confirm Password\n3. Click Submit .\n\nThe user can manage the display preferences of the Active Users list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t\n\n- Click items.\n\n- next to the column name to filter the list and display only the preferred\n\n- Use the pagination option to navigate between different sections of the list. 4\n\n- Use the page size selector to choose the number of items displayed at a time. 20\n\n## Add User\n\nThe Add User option allows the user to add a new user.\n\nPerform the following steps to add an invited user:\n\n1. Click Add User on the Admin page.\n\nThe Add User pop-up appears.\n\n<!-- image -->\n\nSubmit'),
#  Document(metadata={}, page_content="1. Click Add User on the Admin page.\n\nThe Add User pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Provide the necessary information in the following fields:\n1. Email ID: Enter the registered user's Email ID.\n2. Roles: Select the required role from the drop-down.\n3. Click Submit .\n\nAn activation link is sent to the user's email id. After the user account is activated via the link, the user is added to the active users list. For more information, see Active UsersActive Users .\n\n## User Roles\n\nThe User Roles page allows the user to configure different roles. The admin configures the roles and provides the users with permissions to various functions.\n\nClick User Roles on the Admin page. The following page appears:\n\n<!-- image -->\n\nThe User Roles page displays the following information:"),
#  Document(metadata={}, page_content='<!-- image -->\n\nThe User Roles page displays the following information:\n\n- Role Name: Displays the name of the user role.\n- Role Type: Displays the type of user role. The application selects System as the default role type.\n- Action: Displays the available actions. The actions are:\n- Edit\n- Delete\n\n## Add User Role\n\nThe Add Role option in the User Roles page allows the user to add a user role.\n\nPerform the following steps to add a user role:\n\n1. Click Add Role on the User Roles page.\n\n<!-- image -->\n\nThe Add Role pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Provide the necessary information in the following fields:\n1. Role name: Enter the name of the user role.\n\n2. Role Permissions: Select the required checkboxes against the required functionalities to provide permissions.\n1. Select All -Select this checkbox to grant access to all functionalities.\n3. Click Submit .\n\n## Edit User Role\n\nThe edit user role option in the User Roles page allows the user to edit a user role.'),
#  Document(metadata={}, page_content='The edit user role option in the User Roles page allows the user to edit a user role.\n\nPerform the following steps to edit a user role:\n\n<!-- image -->\n\nThe Edit Role pop-up appears.\n\nEdit Role\n\n<!-- image -->\n\nSubmit\n\n2. Edit the necessary information in the required fields.\n3. Click Submit .\n\n## Delete User Role\n\nThe delete user role option in the User Roles page allows the user to delete a user role.\n\nPerform the following steps to delete a user:\n\n1. Click against the respective user role.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n- 0 Do you want to delete this role?\n2. Click Yes to delete the user role or No to cancel.\n\n<!-- image -->\n\nThe user can manage the display preferences of the User roles list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A).\n- Click next to the column name to filter the list and display only the preferred items.\n- Use the pagination\n\n<!-- image -->'),
#  Document(metadata={}, page_content="<!-- image -->\n\nbetween different sections of the list.\n\n- time.\n\n- Use the page size selector to choose the number of items displayed at a\n\n## Update Profile\n\nThe Update Profile option allows the user to edit the profile details.\n\nClick Update Profile on the Admin page. The following pop-up appears:\n\nUpdate Profile\n\n<!-- image -->\n\nPerform the following steps to update the profile:\n\n1. Click Choose profile image to navigate to the user's folder and select a profile image.\n2. Edit the following fields:\n1. First Name: Enter the user's first name.\n2. Last Name: Enter the user's last name.\n3. Phone Number: Enter the user's phone number.\n4. Address: Enter the user's address.\n\n3. Enable the Email Notification and SMS Notification buttons to receive notifications.\n4. Click Submit .\n\n## Templates\n\nThe Templates page allows the users to manage and configure the templates of the organization on the Hierarchy page.\n\nClick Templates on the Admin page. The following page appears:\n\n<!-- image -->"),
#  Document(metadata={}, page_content="Click Templates on the Admin page. The following page appears:\n\n<!-- image -->\n\nThe Templates page displays the following information about a template:\n\n- Template: Displays the type of template.\n- Description: Displays the description of the template\n- Action: Displays the available actions. The actions are:\n- Edit\n- Delete X\n- Configure\n\n## Add Template\n\nThe add template option in the Template page allows the user to add a new template.\n\nPerform the following steps to add a new template:\n\n<!-- image -->\n\n## 1. Click Template on the Templates page.\n\n<!-- image -->\n\nThe Add Template pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n## 2. Fill in the following fields:\n\n1. Name: Enter a template name.\n2. Description: Enter a description for the template.\n3. Template Icon: Click Choose Template Icon to select the template icon from the user's system.\n4. Is it managed site: Select the checkbox if it is a managed site.\n\n3. Click Submit .\n\n## Edit Template"),
#  Document(metadata={}, page_content='3. Click Submit .\n\n## Edit Template\n\nThe edit template option in the Template page allows the user to edit a template.\n\nPerform the following steps to edit a template:\n\n1.\n\n<!-- image -->\n\nThe Edit Template pop-up appears.\n\n<!-- image -->\n\n<!-- image -->\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Template\n\nThe delete template option in the Template page allows the user to delete a template.\n\nPerform the following steps to delete a template.\n\n1. Click against the respective template.\n\n<!-- image -->\n\nThe following pop-up appears:\n\n- Do you want to delete this template?\n\nNo\n\nYes\n\n2. Click Yes to delete the template or click No to cancel.\n\n## Configure Template\n\nThe configure template option in the Template page allows the user to configure a template:\n\nPerform the following steps to configure a template.\n\n1.\n\n<!-- image -->\n\n## The following page appears.\n\n<!-- image -->\n\n2. Click Add Field to add the necessary fields.\n\nThe Select Field Type pop-up appears.'),
#  Document(metadata={}, page_content='2. Click Add Field to add the necessary fields.\n\nThe Select Field Type pop-up appears.\n\n<!-- image -->\n\nSelect Field Type\n\n<!-- image -->\n\n3. Select the required field.\n\nThe Add Field pop-up appears.\n\nAdd Field\n\nName\n\nField required\n\n- [ ] Yes\n\nSubmit\n\n<!-- image -->\n\n4. Fill in the following fields:\n1. Name -Enter a field name.\n2. Field required - Select the Yes checkbox if the field is required.\n5. Click Submit .\n\n## Edit Field\n\nThe edit field option in the template configuration page allows the user to edit a field in the template.\n\nPerform the following steps to edit a field:\n\n1. Click against the required field on the template configuration page.\n\n<!-- image -->\n\nThe Edit Field pop-up appears.\n\n<!-- image -->\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Field\n\nThe delete field option in the template configuration page allows the user to delete a field in the template.\n\nPerform the following steps to delete a field:'),
#  Document(metadata={}, page_content='Perform the following steps to delete a field:\n\n1. Click against the required field on the template configuration page.\n\n<!-- image -->\n\n## The following pop-up appears:\n\n- @ Do you want to delete this field?\n2. Click Yes to delete the field or click No to cancel.\n\n<!-- image -->\n\nThe user can manage the display preferences of the Templates list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t\n- Click next to the column name to filter the list and display only the preferred items.\n- Use the pagination option to navigate between different sections of the list. 2\n- Use the page size selector to choose the number of items displayed at a time. 20\n\n## Hierarchy\n\nThe Hierarchy page allows the user to create a hierarchy using the templates. The following are the available default templates:\n\n- Organization\n- State\n- Site\n\nClick Hierarchy on the Admin page. The following page appears:\n\n<!-- image -->'),
#  Document(metadata={}, page_content='Click Hierarchy on the Admin page. The following page appears:\n\n<!-- image -->\n\nThe user can view the hierarchy generated using templates and associations on the Hierarchy page.\n\n## Add Organization\n\nThe Organization option in the Hierarchy page allows the users to add an organization template.\n\nPerform the following steps to add an organization:\n\n1. Click Organization on the Hierarchy page.\n\n<!-- image -->\n\n## The Add Organization pop-up appears.\n\n<!-- image -->\n\n2. Fill in the following fields:\n1. Name: Enter an organization name.\n2. Description: Enter a description for the organization.\n3. Click Submit. An entity corresponding to the organization is created on the Hierarchy page.\n\n## Add State\n\nThe State option in the Hierarchy page allows the user to add a state template.\n\nPerform the following steps to add a state:\n\n1. Click State on the Hierarchy page.\n\n<!-- image -->\n\n## The Add State pop-up appears.\n\n<!-- image -->'),
#  Document(metadata={}, page_content='<!-- image -->\n\n## The Add State pop-up appears.\n\n<!-- image -->\n\n2. Fill in the following fields:\n1. Name: Enter a state name.\n2. Description: Enter a description for the state.\n3. Click Submit. An entity corresponding to the state is created on the hierarchy page.\n\n## Create Hierarchy\n\nThe user can create a hierarchy by establishing associations between templates on the Hierarchy page.\n\nPerform the following steps to create a hierarchy:\n\n1. Click Enable association mode .\n2. Draw connections between the required entities. The hierarchy is created.\n\n<!-- image -->\n\nTo add sites to the hierarchy, see Site LocationsSite Locations .\n\n## Edit Template\n\nThe edit option on the Hierarchy page allows the user to edit the template.\n\nPerform the following steps to edit a template:\n\n1. On the Hierarchy page, right-click on the respective template.\n\nThe following pop-up appears:\n\n<!-- image -->\n\n2. Click Edit. The Edit Entity pop-up appears.\n3. Edit the necessary fields and click Submit .'),
#  Document(metadata={}, page_content='2. Click Edit. The Edit Entity pop-up appears.\n3. Edit the necessary fields and click Submit .\n\n<!-- image -->\n\n## Delete Template\n\nThe delete option on the Hierarchy page allows the user to delete the template.\n\nPerform the following steps to delete a template:\n\n1. On the Hierarchy page, right-click on the template to delete.\n\nThe following pop-up appears.\n\n<!-- image -->\n\n2. Click Delete. A Confirmation pop-up appears.\n\nConfirmation\n\n<!-- image -->\n\nAre you sure you want to delete this entity?\n\n<!-- image -->\n\n3. Click Yes to delete an entity or click No to cancel.\n\n## Delete Association\n\nThe delete association option in the Hierarchy page allows the user to delete the association.\n\nPerform the following steps to delete an association:\n\n1. On the Hierarchy page, right-click on the respective association. A Confirmation pop-up appears.\n2. Click Yes to delete the association or click No to cancel.\n\n<!-- image -->\n\n## Account'),
#  Document(metadata={}, page_content='<!-- image -->\n\n## Account\n\nThe Account page allows users to configure account details.\n\nPerform the following steps to customize the account:\n\n1. Click Account on the Admin page. The Customize Account pop-up appears.\n\nCustomize Account\n\n<!-- image -->\n\nAccount Name\n\nTemperature Unit\n\nDemo\n\n- [ ] Celsius\n\n- [ ] Fahrenheit\n\nSave\n\n2. Select the required checkbox against the Temperature Unit to set the temperature unit for the application and click Save .\n\n## Site Locations\n\nThe Site Locations page allows the user to create and manage the location of each site.\n\nClick Site Locations on the Admin page. The following page appears:\n\n<!-- image -->\n\nThe Site Locations page displays the available sites and geographical locations.\n\n## Add Site\n\nThe Add Site option in the Site Locations page allows the user to add a site location.\n\nPerform the following steps to add a site:\n\n## 1. Click Add Site on the Site Locations page.\n\n<!-- image -->\n\nThe Add Site pop-up appears.\n\n<!-- image -->'),
#  Document(metadata={}, page_content="<!-- image -->\n\nThe Add Site pop-up appears.\n\n<!-- image -->\n\n2. Fill in the following fields:\n1. Hierarchy: From the drop-down, select the required hierarchy.\n2. Name: Enter the site name.\n3. Description: Enter a description for the site.\n4. Geographical Location: Enter the name of the location in the field or select from the map to choose the location.\n5. Site image: Click Choose site Image to navigate to the user's file location and select the required site image.\n3. Click Submit .\n\n## Edit Site\n\nThe Edit option in the Site Locations page allows the user to edit a site location\n\nPerform the following steps to edit a site location:\n\n<!-- image -->\n\nThe Edit Site pop-up appears.\n\n<!-- image -->\n\nSubmit\n\n2. Edit the necessary fields and click Submit .\n\n## Delete Site\n\nThe delete site option in the Site Locations page allows the user to delete a site location.\n\nPerform the following steps to delete a site location:\n\n<!-- image -->\n\nThe following pop-up appears:"),
#  Document(metadata={}, page_content='<!-- image -->\n\nThe following pop-up appears:\n\n2. Click Yes to delete the site location.\n\nThe site location is deleted.\n\n## Audit\n\nThe Audit page displays the log of all the activity within the application. The Audit page also provides the relevant data of the activities done along with the date and time of the activity.\n\nClick Audit from the Admin page. The following page appears:\n\n<!-- image -->\n\nThe Audit page displays the following fields:\n\n- Created Time: Displays the date and time of the activity.\n- Title: Displays the title of the activity.\n- Description: Displays the description of the activity.\n\nThe user can manage the display preferences of the Audit list using the following options:'),
#  Document(metadata={}, page_content='The user can manage the display preferences of the Audit list using the following options:\n\n- Click next to the column name to sort the list in either ascending(A-Z) or descending order(Z-A). t\n- Click next to the column name to filter the list and display only the preferred items.\n- Use the pagination option to navigate between different sections of the list.\n- Use the page size selector to choose the number of items displayed at a time.\n\n## Troubleshooting'),
#  Document(metadata={}, page_content='1. Unable to log in to the ATT page:\n1. Check Username and Password: Ensure the username and password are entered correctly.\n2. Spelling: Verify that there are no typos in the username or password.\n3. Ensure Caps Lock is Off: Check whether Caps Lock is inadvertently enabled.\n4. Forgotten Password: If you can\'t remember the password, Reset Password "can\'t login" link on the login screen. You may be able to reset it via email.\n5. Multiple Failed Login Attempts: After several unsuccessful login attempts, systems lock the account temporarily for security reasons. If this is the case, contact the service provider to unlock the account.\n6. Browser Issues: If you\'re logging in via a web browser, try clearing your browser\'s cache, cookies, and history. Also, perform a hard refresh (Ctrl+Shift+R) Sometimes, old session data can prevent a successful login.'),
#  Document(metadata={}, page_content="7. Browser Compatibility: If you're using a web browser and unable to log in, try switching to a different browser or use an incognito/private browsing mode.\n8. Account Recovery: If none of the above step's work and you're still unable to log in, contact customer care via email- id: netvire.support@thinkpalm.com They may be able to assist with\n10. account recovery or provide more specific troubleshooting for the service."),
#  Document(metadata={}, page_content="## 2. Gateway is down:\n\n1. Check the gateway status is showing up or down in the gateway page also check the last seen of the gateway.\n\n2. Check the validity of your SIM card to ensure your subscription hasn't expired. Confirm that your SIM's service is still active to avoid any disruptions.\n\n## 3. Check Power and Connectivity:\n\n1. Ensure the edge device is powered on and connected to the network.\n2. Verify that all cables are securely connected and there are no loose connections.\n4. LED Indicators: Check if the LED status lights on the gateway are steady.\n5. Power Cycle: Unplug the gateway (modem), wait for 10 minutes then plug it back in. This can resolve many temporary issues.\n6. If none of the above solutions work, please contact customer care via mail -id: netvire.support@thinkpalm.com .\n\n## 3. Data not updating in the connected Devices:"),
#  Document(metadata={}, page_content='## 3. Data not updating in the connected Devices:\n\n1. Check the gateway is up or down in the gateway page.\n2. Check the signal status and battery Health.\n3. Check the device last updated time and date.\n4. Check for any network outages or disruptions.\n5. If the issue persists after troubleshooting, it may be a device-specific or firmware issue. Contact customer support for further assistance via mailid: netvire.support@thinkpalm.com. They will be able to provide firmware updates, advanced troubleshooting, or a hardware replacement.\n\n## 4. Events not triggering in Events page:\n\n1. Check the Gateway up or down.\n2. Check the device status.\n3. Check the Events rules settings to ensure it is configured to trigger the events. (make sure correct device is selected in the event rule condition).\n4. Check that event repeat interval is blank if so, open event will not repeat.\n5. Check if the threshold levels (temperature, humidity, CO2, etc.) are set correctly for triggering the alarm.'),
#  Document(metadata={}, page_content="6. Ensure that there is no interference that could be disrupting the communication between the devices system and the dashboard (e.g., WiFi interference, physical obstructions).\n7. Ensure that environmental conditions (like lighting or temperature) aren't preventing proper detection for sensor.\n8. The alarm is still not triggering the dashboard, contact the customer support team via mail -id: netvire.support@thinkpalm.com .\n\n## 5. Report Not Generating correctly:"),
#  Document(metadata={}, page_content='## 5. Report Not Generating correctly:\n\n1. Check the start end time of the report.\n2. Verify that the devices or sensors are operational and transmitting data.\n3. Check the filters or criteria set for the report. If the filters are too restrictive (e.g., an incorrect date range, specific sites, or user permissions), the report might fail to generate.\n4. For instant report will only be generated for events occurring within the specified date range.\n5. Review User Permissions to ensure the correct access rights for generating reports.\n6. Clear Cache or Refresh the dashboard and test again.\n7. If none of the above solutions work, please contact customer care via mail -id: netvire.support@thinkpalm.com .\n\n## Maintenance'),
#  Document(metadata={}, page_content='## Maintenance\n\n- Check Sensor Placement for obstructions and correct positioning.\n- Clean the Sensors with a soft cloth or compressed air.\n- Inspect and Replace Batteries as needed.\n- Test Sensor Functionality by manually triggering the sensor and checking for response.\n- Update Firmware/Software to keep sensors running efficiently.\n- Check for Obstructions/Interference that could affect performance.Monitor Signal Strength (for wireless sensors) and eliminate any interference.\n- Inspect for Physical Wear and Tear or damage and replace faulty components.')]

# %%
# #to know no of token
# import tiktoken
# encoding = tiktoken.encoding_for_model("gpt-4o-mini")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 #to know no of token
# ----> 2 import tiktoken
#       3 encoding = tiktoken.encoding_for_model("gpt-4o-mini")
#
# ModuleNotFoundError: No module named 'tiktoken'

# %% [markdown]
# ### Document Vector Embedding

# %%
from langchain_ollama import OllamaEmbeddings

import faiss
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore

# %%
embeddings = OllamaEmbeddings(model='nomic-embed-text', base_url="http://localhost:11434")

single_vector = embeddings.embed_query("this is some text data my name is thinkpalm")

# %%
len(single_vector)
# Out:
# 768

# %%
index = faiss.IndexFlatL2(len(single_vector))
index.ntotal, index.d
# Out:
# (0, 768)

# %%
vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={}
)

# %%
# store documents
ids = vector_store.add_documents(documents=chunks)

# %%
vector_store.index_to_docstore_id
len(ids)
# Out:
# 61

# %%
db_name = "smart_iot_vector_store"
vector_store.save_local(db_name)

new_vector_store = FAISS.load_local(db_name, embeddings=embeddings, allow_dangerous_deserialization=True)
len(new_vector_store.index_to_docstore_id)
# Out:
# 61

# %% [markdown]
# ### Retrieval

# %%
question = "where can i see the status of the devices installed?"
docs = new_vector_store.search(query=question, search_type='similarity')
for doc in docs:
    print(doc.page_content)
    print("\n\n")
# Out:
# The Devices page displays the list of available devices with the following details:
#
# - · Name: Displays the name of the device.
# - · Status/Last Value: Displays the current value from the device.
# - · Device Type: Displays the type of the device.
# - · Battery: Displays the battery strength of the device.
# - · Signal: Displays the signal strength of the device.
# - · Location: Displays the site where the device is installed.
# - · Last Seen: Displays the date and time when the device is last connected.
# - · Action: Displays the actions available for the device. The actions are:
# - · Edit
#
# <!-- image -->
#
# - · Delete
#
# <!-- image -->
#
# Click to view the graphical representation of the device history. Hover over the graph to see the device status at a specific date and time.
#
# <!-- image -->
#
# ## Device Dashboard
#
# The device dashboard provides detailed information about the device. Click on the device name to view the dashboard.
#
# <!-- image -->
#
# The device dashboard displays the following information:
#
#
#
# ## Dashboard
#
# The Dashboard provides users with information about the devices installed at all locations. Users can view the status, history, and statistics of each device on the sites. Click Dashboard from the left panel. The following page appears:
#
# <!-- image -->
#
# The Dashboard provides the user with the following options:
#
# - · Status: Displays the current status of the devices installed along with the last connected date and time. Click on the site icon on the device information to go to the site dashboard.
#
# NetvirE Retail
#
# <!-- image -->
#
# To change the layout of the dashboard, drag the sensor information to the required position and click Save. The Save button appears only when the user changes the layout. Click Reset to reset the previous layout.
#
# - · History: Displays the history of the devices installed using graphical representations.
#
# <!-- image -->
#
# The graph is plotted using the measured value of each device against time.
#
#
#
# <!-- image -->
#
# The device dashboard displays the following information:
#
# - · Device Information: Displays the device details such as:
# - · DevUI: Displays the unique DevUI ID.
#
# Last seen: Displays the date and time when the device is last connected.
#
# - · Battery Status: Displays the battery status of the device.
# - · Signal Status: Displays the signal strength of the device.
# - · Events: Displays the number of events generated on the device.
# - · Current Status: Displays the current status according to the device property.
# - · History: Displays the graphical representation of the device history.
#
# ## Add Device
#
# The Add Device option allows the user to add a device. Perform the following steps to add a new device:
#
# ## 1. Click Add Device on the Devices page.
#
# <!-- image -->
#
# ## The Add Device pop-up appears.
#
# <!-- image -->
#
# Submit
#
# - 2. Fill in the following fields:
# - 1. Name: Enter the name of the device.
# - 2. Device Type: Select the required device type from the drop-down.
#
#
#
# <!-- image -->
#
# Search for the required site from the list using the Search Site option.
#
# The Sites pop-up displays the list of all sites along with the following information:
#
# - · Number of devices installed on the sites.
# - · Number of gateways connected to the sites.
# - · Number of alarms generated on the site.
#
# The user can view the site location on the map using the icon. Click View to navigate to the site dashboard. For more information, see Site DashboardSite Dashboard .
#
# ## Site Dashboard
#
# The site dashboard provides the user with the status, history, and statistics of the devices installed on the site. The user can access the site dashboard from the site location icon on the map or through the Sites pop-up. The site dashboard appears as follows:
#
# <!-- image -->
#
# The site dashboard provides the user with the following options:
#
# - · Status: Displays the current status of the devices installed on the site along with the last connected date and time.
#
# <!-- image -->

# %%
# converting the above cell as retriever
retriever = new_vector_store.as_retriever(search_type="mmr", search_kwargs = {'k': 3, 
                                                                          'fetch_k': 100,
                                                                          'lambda_mult': 1})

# %%
docs = retriever.invoke(question)

for doc in docs:
    print(doc.page_content)
    print("\n\n")
# Out:
# The Devices page displays the list of available devices with the following details:
#
# - · Name: Displays the name of the device.
# - · Status/Last Value: Displays the current value from the device.
# - · Device Type: Displays the type of the device.
# - · Battery: Displays the battery strength of the device.
# - · Signal: Displays the signal strength of the device.
# - · Location: Displays the site where the device is installed.
# - · Last Seen: Displays the date and time when the device is last connected.
# - · Action: Displays the actions available for the device. The actions are:
# - · Edit
#
# <!-- image -->
#
# - · Delete
#
# <!-- image -->
#
# Click to view the graphical representation of the device history. Hover over the graph to see the device status at a specific date and time.
#
# <!-- image -->
#
# ## Device Dashboard
#
# The device dashboard provides detailed information about the device. Click on the device name to view the dashboard.
#
# <!-- image -->
#
# The device dashboard displays the following information:
#
#
#
# ## Dashboard
#
# The Dashboard provides users with information about the devices installed at all locations. Users can view the status, history, and statistics of each device on the sites. Click Dashboard from the left panel. The following page appears:
#
# <!-- image -->
#
# The Dashboard provides the user with the following options:
#
# - · Status: Displays the current status of the devices installed along with the last connected date and time. Click on the site icon on the device information to go to the site dashboard.
#
# NetvirE Retail
#
# <!-- image -->
#
# To change the layout of the dashboard, drag the sensor information to the required position and click Save. The Save button appears only when the user changes the layout. Click Reset to reset the previous layout.
#
# - · History: Displays the history of the devices installed using graphical representations.
#
# <!-- image -->
#
# The graph is plotted using the measured value of each device against time.
#
#
#
# <!-- image -->
#
# The device dashboard displays the following information:
#
# - · Device Information: Displays the device details such as:
# - · DevUI: Displays the unique DevUI ID.
#
# Last seen: Displays the date and time when the device is last connected.
#
# - · Battery Status: Displays the battery status of the device.
# - · Signal Status: Displays the signal strength of the device.
# - · Events: Displays the number of events generated on the device.
# - · Current Status: Displays the current status according to the device property.
# - · History: Displays the graphical representation of the device history.
#
# ## Add Device
#
# The Add Device option allows the user to add a device. Perform the following steps to add a new device:
#
# ## 1. Click Add Device on the Devices page.
#
# <!-- image -->
#
# ## The Add Device pop-up appears.
#
# <!-- image -->
#
# Submit
#
# - 2. Fill in the following fields:
# - 1. Name: Enter the name of the device.
# - 2. Device Type: Select the required device type from the drop-down.

# %% [markdown]
# ### Generation with LLAMA3.2 1b on OLLAMA

# %%
from langchain import hub #TO PULL RAG PROMPTS
from langchain_core.output_parsers import StrOutputParser # GETTING FINAL OUT AS STRING
from langchain_core.runnables import RunnablePassthrough #parse question and context directly to LLM
from langchain_core.prompts import ChatPromptTemplate #to pass prompt with context (chunk of data)

from langchain_ollama import ChatOllama
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
prompt = """
You are a chatbot assistant for Smart Business IoT, designed to provide precise and accurate answers strictly based on the provided context. 
You have access to ingested document related to Smart Business IoT, an application that allows the user to view and manage the data of
various sensors installed on different sites. The user can monitor data focusing on light
intensity, temperature, humidity, and carbon dioxide levels through installed devices.
The application connects multiple sites and acts as a single data point. The user can
add events, set event rules, generate reports based on the collected data, and manage
administration through the application.
### Guidelines:
1. Provide answers **strictly** based on the given context.  
- If the answer is **not available**, respond with: "I'm sorry, I don't have that information."
2. Ensure responses are **clear, concise, and directly relevant** to the question.
3. **Do not** answer questions outside the scope of the provided context.

Question: {question}  
Context: {context}  
Answer:
"""

# %%
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])
# print(format_docs(docs))

model = ChatOllama(
    model="llama3.2:1b",
    base_url="http://localhost:11434",
    streaming=True,  # Enable streaming
    callbacks=[StreamingStdOutCallbackHandler()],  # Print tokens as they are generated
)

# %%
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])
# print(format_docs(docs))

model = ChatOllama(
    model="phi4:latest",
    base_url="http://192.168.0.49:2255",
    streaming=True,  # Enable streaming
    callbacks=[StreamingStdOutCallbackHandler()],  # Print tokens as they are generated
)

# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv
load_dotenv()
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])
# print(format_docs(docs))

model = ChatGroq(
            groq_api_key=os.getenv("GROQ_API_KEY"),
            model="llama3-70b-8192",
            streaming=True,
            callbacks=[StreamingStdOutCallbackHandler()],  # Print tokens as they are generated
            # model="qwen-qwq-32b"
        )

# %%
prompt = ChatPromptTemplate.from_template(prompt)
rag_chain = (
    {"context": retriever|format_docs, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
question = "where can i see the status of the devices installed?"
output = rag_chain.invoke(question)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 question = "where can i see the status of the devices installed?"
# ----> 2 output = rag_chain.invoke(question)
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_core/runnables/base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)
#     857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_ollama/chat_models.py:644, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     637 def _generate(
#     638     self,
#     639     messages: List[BaseMessage],
#    (...)
#     642     **kwargs: Any,
#     643 ) -> ChatResult:
# --> 644     final_chunk = self._chat_stream_with_aggregation(
#     645         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     646     )
#     647     generation_info = final_chunk.generation_info
#     648     chat_generation = ChatGeneration(
#     649         message=AIMessage(
#     650             content=final_chunk.text,
#    (...)
#     654         generation_info=generation_info,
#     655     )
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_ollama/chat_models.py:545, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     536 def _chat_stream_with_aggregation(
#     537     self,
#     538     messages: List[BaseMessage],
#    (...)
#     542     **kwargs: Any,
#     543 ) -> ChatGenerationChunk:
#     544     final_chunk = None
# --> 545     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     546         if not isinstance(stream_resp, str):
#     547             chunk = ChatGenerationChunk(
#     548                 message=AIMessageChunk(
#     549                     content=(
#    (...)
#     562                 ),
#     563             )
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/langchain_ollama/chat_models.py:527, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     517     yield self._client.chat(
#     518         model=params["model"],
#     519         messages=ollama_messages,
#    (...)
#     524         tools=kwargs["tools"],
#     525     )
#     526 else:
# --> 527     yield from self._client.chat(
#     528         model=params["model"],
#     529         messages=ollama_messages,
#     530         stream=True,
#     531         options=Options(**params["options"]),
#     532         keep_alive=params["keep_alive"],
#     533         format=params["format"],
#     534     )
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/ollama/_client.py:160, in Client._request.<locals>.inner()
#     159 def inner():
# --> 160   with self._client.stream(*args, **kwargs) as r:
#     161     try:
#     162       r.raise_for_status()
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpx/_client.py:880, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     857 """
#     858 Alternative to `httpx.request()` that streams the response body
#     859 instead of loading it into memory at once.
#    (...)
#     865 [0]: /quickstart#streaming-responses
#     866 """
#     867 request = self.build_request(
#     868     method=method,
#     869     url=url,
#    (...)
#     878     extensions=extensions,
#     879 )
# --> 880 response = self.send(
#     881     request=request,
#     882     auth=auth,
#     883     follow_redirects=follow_redirects,
#     884     stream=True,
#     885 )
#     886 try:
#     887     yield response
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      97 except BaseException as exc:
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      74 with self._request_lock:
#      75     if self._connection is None:
# ---> 76         stream = self._connect(request)
#      78         ssl_object = stream.get_extra_info("ssl_object")
#      79         http2_negotiated = (
#      80             ssl_object is not None
#      81             and ssl_object.selected_alpn_protocol() == "h2"
#      82         )
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpcore/_sync/connection.py:122, in HTTPConnection._connect(self, request)
#     114     kwargs = {
#     115         "host": self._origin.host.decode("ascii"),
#     116         "port": self._origin.port,
#    (...)
#     119         "socket_options": self._socket_options,
#     120     }
#     121     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122         stream = self._network_backend.connect_tcp(**kwargs)
#     123         trace.return_value = stream
#     124 else:
#
# File ~/vs_projects/pdf_quer_llm/.envrag/lib/python3.10/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#     212         sock.setsockopt(*option)  # pragma: no cover
#
# File /usr/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     843 if source_address:
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#     847 err = None
#
# KeyboardInterrupt:
